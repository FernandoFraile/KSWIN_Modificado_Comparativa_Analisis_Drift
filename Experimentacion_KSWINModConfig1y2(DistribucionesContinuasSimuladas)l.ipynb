# %% [markdown]
# # Pruebas KSWIN Modificado (configuracion 1 y 2)- Monitorización de datos procedentes de distribuciones cotinuas simuladas

# %% [markdown]
# ## Importación y carga de librerías

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib import gridspec
from KSWIN_modificado import KSWIN_modificado
import collections
import pandas as pd 
from Lock import excel_lock
from KSWIN_modificado import KSWIN_modificado
from river import drift
import time
from KSWIN_modificado import KSWIN_modificado

# %% [markdown]
# ## Creación de Datasets para pruebas

# %% [markdown]
# ### Abrupto

# %%
# ----------------------------------------------------------
# Función para generar un conjunto de datos con 'abrupt drift'
# ----------------------------------------------------------
def crear_dataset_abrupto_General(seed_aux: int = 42, ruido_std: float = 0.1, distribucion: str = "normal"):
    """
    Genera un conjunto de datos sintético que simula un 'abrupt drift' en una distribución.

    Parámetros:
    - seed_aux (int): semilla aleatoria para garantizar reproducibilidad.
    - ruido_std (float): desviación estándar del ruido que se añade a los datos.
    - distribucion (str): tipo de distribución a utilizar ('normal', 'exponential', 'gamma').

    Retorna:
    - data_noisy (np.ndarray): datos generados con ruido y drift incorporado.
    - drifts (dict): diccionario con información sobre la localización del 'abrupt drift'.
    """

    # Diccionario para registrar información de distintos tipos de concept drift
    drifts = {
        "drift_abrupto": [],  # abrupt drift
        "drift_gradual": [],
        "drift_incremental": [],
        "drift_recurrente": []
    }

    # Establecer la semilla para reproducibilidad
    np.random.seed(seed_aux)

    # Número total de muestras y punto exacto donde ocurre el drift
    n_samples = 30000
    drift_point = 15000

    # Parámetros para la distribución antes del drift
    loc1 = np.random.uniform(0, 5)
    scale1 = np.random.uniform(0.5, 1.5)

    # Parámetros para la distribución después del drift
    loc2 = np.random.uniform(0, 5)
    scale2 = np.random.uniform(0.5, 1.5)

    # Generar los datos según la distribución seleccionada
    if distribucion == "normal":
        data_before_drift = np.random.normal(loc=loc1, scale=scale1, size=drift_point)
        data_after_drift = np.random.normal(loc=loc2, scale=scale2, size=n_samples - drift_point)
    elif distribucion == "exponential":
        data_before_drift = np.random.exponential(scale1, drift_point)
        data_after_drift = np.random.exponential(scale2, n_samples - drift_point)
    elif distribucion == "gamma":
        data_before_drift = np.random.gamma(loc1, scale1, drift_point)
        data_after_drift = np.random.gamma(loc2, scale2, n_samples - drift_point)
    else:
        raise ValueError("Error: la distribución especificada no existe.")

    # Unir las dos partes del conjunto de datos
    data = np.concatenate((data_before_drift, data_after_drift))

    # Generar ruido gaussiano
    noise = np.random.normal(loc=0.0, scale=ruido_std, size=n_samples)

    # Añadir el ruido, teniendo en cuenta la distribución
    if distribucion in ["normal", "logistic"]:
        data_noisy = data + noise
    elif distribucion in ["exponential", "gamma"]:
        # Se evitan valores negativos en distribuciones definidas en R+
        data_noisy = np.clip(data + noise, a_min=0, a_max=None)
    else:
        raise ValueError("Error: la distribución especificada no existe.")

    # Registrar el punto donde ocurre el abrupt drift
    drifts["drift_abrupto"].append({"punto": drift_point, "detectado": False})

    return data_noisy, drifts

# %% [markdown]
# ### Gradual

# %%
# ----------------------------------------------------------
# Función sigmoide para controlar la transición gradual
# ----------------------------------------------------------
def sigmoide(x, x0=0, k=1, L=1):
    """
    Función sigmoide estándar para calcular la probabilidad de transición entre dos distribuciones.

    Parámetros:
    - x (np.ndarray): valores de entrada.
    - x0 (float): punto de inflexión de la curva sigmoide.
    - k (float): pendiente de la sigmoide.
    - L (float): valor máximo de la función (por defecto 1).

    Retorna:
    - y (np.ndarray): valores de salida de la función sigmoide.
    """
    y = L / (1 + np.exp(-k * (x - x0)))
    return y

# ----------------------------------------------------------
# Función para generar un conjunto de datos con 'gradual drift'
# ----------------------------------------------------------
def crear_dataset_gradual_General(seed_aux: int = 42, ruido_std: float = 0.1, distribucion: str = "normal"):
    """
    Genera un conjunto de datos sintético que simula un 'gradual drift' mediante una transición sigmoide.

    Parámetros:
    - seed_aux (int): semilla para garantizar reproducibilidad.
    - ruido_std (float): desviación estándar del ruido añadido.
    - distribucion (str): tipo de distribución ('normal', 'exponential', 'gamma').

    Retorna:
    - data_noisy (np.ndarray): datos con ruido y drift gradual incorporado.
    - drifts (dict): información sobre el intervalo donde ocurre el 'gradual drift'.
    """

    drifts = {
        "drift_abrupto": [],
        "drift_gradual": [],
        "drift_incremental": [],
        "drift_recurrente": []
    }

    # Establecer semilla para reproducibilidad
    np.random.seed(seed_aux)

    # Número total de muestras y punto donde comienza el drift
    n_samples = 30000
    drift_point = 15000

    # Parámetros de la distribución antes del drift
    loc1 = np.random.uniform(0, 5)
    scale1 = np.random.uniform(0.5, 1.5)

    # Parámetros de la distribución después del drift
    loc2 = np.random.uniform(0, 5)
    scale2 = np.random.uniform(0.5, 1.5)

    # Longitud de la transición gradual (aleatoria)
    tamanho = np.random.choice([1000, 2000, 3000])

    # Generar datos antes y después de la transición, según la distribución
    if distribucion == "normal":
        data_before_drift = np.random.normal(loc=loc1, scale=scale1, size=drift_point)
        data_after_drift = np.random.normal(loc=loc2, scale=scale2, size=n_samples - drift_point - tamanho)
    elif distribucion == "exponential":
        data_before_drift = np.random.exponential(scale1, drift_point)
        data_after_drift = np.random.exponential(scale2, n_samples - drift_point - tamanho)
    elif distribucion == "gamma":
        data_before_drift = np.random.gamma(loc1, scale1, drift_point)
        data_after_drift = np.random.gamma(loc2, scale2, n_samples - drift_point - tamanho)
    else:
        raise ValueError("Error: la distribución especificada no existe")

    # Crear probabilidades de transición con una función sigmoide
    x = np.arange(tamanho)
    y = sigmoide(x, x0=tamanho/2, k=8/tamanho, L=1)

    # Generar los datos de transición usando una mezcla probabilística controlada
    data_transition = np.zeros(tamanho)
    for i in range(tamanho):
        # Selección estocástica de distribución basada en la sigmoide
        random_choices = np.random.choice([0, 1], size=1, p=[1 - y[i], y[i]])
        if random_choices == 0:
            data_transition[i] = np.random.normal(loc=loc1, scale=scale1, size=1)[0]
        else:
            data_transition[i] = np.random.normal(loc=loc2, scale=scale2, size=1)[0]

    # Concatenar las tres partes: antes del drift, transición, y después del drift
    data = np.concatenate((data_before_drift, data_transition, data_after_drift))

    # Generar y añadir ruido gaussiano
    noise = np.random.normal(loc=0.0, scale=ruido_std, size=n_samples)

    if distribucion in ["normal", "logistic"]:
        data_noisy = data + noise
    elif distribucion in ["exponential", "gamma"]:
        data_noisy = np.clip(data + noise, a_min=0, a_max=None)
    else:
        raise ValueError("Error: la distribución especificada no existe")

    # Registrar el intervalo del gradual drift (como incremental en este caso)
    drifts["drift_incremental"].append({
        "inicio": drift_point,
        "fin": drift_point + tamanho,
        "detectado": False
    })

    return data_noisy, drifts

# %% [markdown]
# ### Incremental

# %%
# ----------------------------------------------------------
# Función para generar un conjunto de datos con 'incremental drift'
# ----------------------------------------------------------

def crear_dataset_incremental_General(seed_aux: int = 42, ruido_std: float = 0.1, distribucion: str = "normal"):
    """
    Genera un conjunto de datos sintético que simula un 'incremental drift' mediante interpolación lineal
    de los parámetros de la distribución.

    Parámetros:
    - seed_aux (int): semilla para garantizar reproducibilidad.
    - ruido_std (float): desviación estándar del ruido añadido.
    - distribucion (str): tipo de distribución ('normal', 'exponential', 'gamma').

    Retorna:
    - data_noisy (np.ndarray): datos con ruido y 'incremental drift' incorporado.
    - drifts (dict): información sobre el intervalo donde ocurre el drift.
    """

    drifts = {
        "drift_abrupto": [],
        "drift_gradual": [],
        "drift_incremental": [],
        "drift_recurrente": []
    }

    # Semilla para reproducibilidad
    np.random.seed(seed_aux)

    # Número total de muestras y punto inicial del drift
    n_samples = 30000
    drift_point = 15000

    # Parámetros iniciales y finales de la distribución
    loc1 = np.random.uniform(0, 5)
    scale1 = np.random.uniform(0.5, 1.5)

    loc2 = np.random.uniform(0, 5)
    scale2 = np.random.uniform(0.5, 1.5)

    # Longitud del intervalo de transición (incremental)
    tamanho = np.random.choice([1000, 2000, 3000])

    # Generar los datos antes y después del drift
    if distribucion == "normal":
        data_before_drift = np.random.normal(loc=loc1, scale=scale1, size=drift_point)
        data_after_drift = np.random.normal(loc=loc2, scale=scale2, size=n_samples - drift_point - tamanho)
    elif distribucion == "exponential":
        data_before_drift = np.random.exponential(scale1, drift_point)
        data_after_drift = np.random.exponential(scale2, n_samples - drift_point - tamanho)
    elif distribucion == "gamma":
        data_before_drift = np.random.gamma(loc1, scale1, drift_point)
        data_after_drift = np.random.gamma(loc2, scale2, n_samples - drift_point - tamanho)
    else:
        raise ValueError("Error: la distribución especificada no existe")

    # Interpolación lineal de parámetros para transición incremental
    alpha = np.linspace(0, 1, num=tamanho)
    transition_mean = (1 - alpha) * loc1 + alpha * loc2
    transition_std = (1 - alpha) * scale1 + alpha * scale2

    # Generar datos de transición con parámetros interpolados
    data_transition = np.random.normal(loc=transition_mean, scale=transition_std)

    # Concatenar los tres segmentos: antes, transición, después
    data = np.concatenate((data_before_drift, data_transition, data_after_drift))

    # Generar ruido gaussiano
    noise = np.random.normal(loc=0.0, scale=ruido_std, size=n_samples)

    # Añadir ruido según tipo de distribución
    if distribucion in ["normal", "logistic"]:
        data_noisy = data + noise
    elif distribucion in ["exponential", "gamma"]:
        data_noisy = np.clip(data + noise, a_min=0, a_max=None)
    else:
        raise ValueError("Error: la distribución especificada no existe")

    # Registrar el intervalo del incremental drift
    drifts["drift_incremental"].append({
        "inicio": drift_point,
        "fin": drift_point + tamanho,
        "detectado": False
    })

    return data_noisy, drifts

# %% [markdown]
# ## Funciones utilizadas en la experimentación

# %% [markdown]
# ### Función para graficar

# %%
# ----------------------------------------------------------
# Función para visualizar un conjunto de datos con 'concept drift'
# ----------------------------------------------------------
def plot_data(dataset, drift_detectados, drifts):
    """
    Visualiza el conjunto de datos con sus valores y líneas verticales indicando
    los puntos o intervalos de distintos tipos de 'concept drift'.

    Parámetros:
    - dataset (np.ndarray): conjunto de datos a visualizar.
    - drift_detectados (list[int] o None): lista de índices donde se detectó drift
      mediante algún método automático (se marcan en rojo).
    - drifts (dict): diccionario que contiene información de los drift reales generados
      por tipo: 'drift_abrupto', 'drift_gradual', 'drift_incremental', 'drift_recurrente'.

    Tipos de líneas:
    - 'Drift Detectado': línea roja discontinua (predicciones o detecciones).
    - 'Drift Abrupto': línea azul discontinua en la posición del cambio.
    - 'Drift Gradual': dos líneas verdes delimitando el intervalo de transición.
    - 'Drift Incremental': dos líneas marrones delimitando el cambio progresivo.
    - 'Drift Recurrente': dos líneas amarillas marcando repeticiones cíclicas.

    Retorna:
    - No retorna ningún valor. La función muestra una figura matplotlib.
    """
    fig = plt.figure(figsize=(12, 6))
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1])
    
    ax0 = plt.subplot(gs[0])
    ax0.set_title('Dataset')
    ax0.plot(dataset, 'o', label='Datos')
    ax0.set_ylabel('Valor')
    
    legend_labels = []
    
    # Detecciones automáticas (si existen)
    if drift_detectados is not None:
        for punto in drift_detectados:
            ax0.axvline(x=punto, color='r', linestyle='--',
                        label='Drift Detectado' if 'Drift Detectado' not in legend_labels else '')
        legend_labels.append('Drift Detectado')
    
    # Visualizar cada tipo de drift simulado
    for punto in drifts.get("drift_abrupto", []):
        ax0.axvline(x=punto.get("punto"), color='b', linestyle='--',
                    label='Drift Abrupto' if 'Drift Abrupto' not in legend_labels else '')
        legend_labels.append('Drift Abrupto')
    
    for punto in drifts.get("drift_gradual", []):
        ax0.axvline(x=punto.get("inicio"), color='g', linestyle='--',
                    label='Drift Gradual' if 'Drift Gradual' not in legend_labels else '')
        ax0.axvline(x=punto.get("fin"), color='g', linestyle='--')
        legend_labels.append('Drift Gradual')
    
    for punto in drifts.get("drift_incremental", []):
        ax0.axvline(x=punto.get("inicio"), color='brown', linestyle='--',
                    label='Drift Incremental' if 'Drift Incremental' not in legend_labels else '')
        ax0.axvline(x=punto.get("fin"), color='brown', linestyle='--')
        legend_labels.append('Drift Incremental')
    
    for punto in drifts.get("drift_recurrente", []):
        ax0.axvline(x=punto.get("inicio"), color='y', linestyle='--',
                    label='Drift Recurrente' if 'Drift Recurrente' not in legend_labels else '')
        ax0.axvline(x=punto.get("fin"), color='y', linestyle='--')
        legend_labels.append('Drift Recurrente')
    
    ax0.legend()
    plt.show()

# %% [markdown]
# ### Detección de drift

# %%
# ----------------------------------------------------------
# Función para realizar la detección de 'concept drift' sobre un dataset
# ----------------------------------------------------------
def realizar_deteccion(dataset, drifts, detector, longitud_batch, falsas_alarmas, imprimir_mensajes: bool = True):
    """
    Ejecuta un detector de 'concept drift' sobre un conjunto de datos y compara las detecciones
    con los puntos de drift reales para identificar aciertos y falsas alarmas.

    Parámetros:
    - dataset (np.ndarray): conjunto de datos sobre el que se aplicará la detección.
    - drifts (dict): diccionario con los drifts reales generados por tipo (abrupt, gradual, incremental, recurrente).
    - detector (objeto): instancia de un detector compatible con .update() y .drift_detected.
    - longitud_batch (int): tamaño de la ventana para alimentar al detector.
    - falsas_alarmas (list): lista externa que se irá completando con los índices de falsas alarmas.
    - imprimir_mensajes (bool): si True, se imprime por pantalla cada detección realizada.

    Retorna:
    - tuple:
        - puntos_detectados (list): índices donde se detectó un drift real.
        - falsas_alarmas (list): índices de falsas alarmas (detecciones fuera de ventanas esperadas).
    """

    # Selección del buffer adecuado según el tipo de detector
    if isinstance(detector, KSWIN_modificado):
        batch_detector = collections.deque(maxlen=longitud_batch)
    else:
        batch_detector = collections.deque(maxlen=1)

    puntos_detectados = []

    for i, val in enumerate(dataset):
        # Reinicio del contador si se está en un punto de inicio o fin de algún drift
        for punto in drifts["drift_abrupto"]:
            if punto.get("punto") in [i, i + 2000]:
                iteracciones = 0
                break
        for punto in drifts["drift_gradual"]:
            if i in [punto.get("inicio"), punto.get("fin")]:
                iteracciones = 0
                break
        for punto in drifts["drift_incremental"]:
            if i in [punto.get("inicio"), punto.get("fin")]:
                iteracciones = 0
                break
        for punto in drifts["drift_recurrente"]:
            if i in [punto.get("inicio"), punto.get("fin")]:
                iteracciones = 0
                break

        # Alimentar el detector
        batch_detector.append(val)

        if len(batch_detector) == batch_detector.maxlen:
            if isinstance(detector, KSWIN_modificado):
                detector.update(batch_detector)
            else:
                detector.update(val)

            batch_detector.clear()

            # Si el detector ha identificado drift
            if detector.drift_detected:
                if imprimir_mensajes:
                    print(f'Drift detectado en el índice {i}')

                flag = True  # Marca para indicar si es falsa alarma

                # Verificar si el punto está dentro de alguna ventana de drift real
                for punto in drifts["drift_abrupto"]:
                    if i < punto.get("punto"):
                        punto["detectado"] = True
                    if punto.get("punto") < i < punto.get("punto") + 2000:
                        punto["detectado"] = True
                        flag = False
                        break

                for punto in drifts["drift_gradual"]:
                    if i < punto.get("inicio"):
                        punto["detectado"] = True
                    if punto.get("inicio") < i < punto.get("fin"):
                        punto["detectado"] = True
                        flag = False
                        break

                for punto in drifts["drift_incremental"]:
                    if i < punto.get("inicio"):
                        punto["detectado"] = True
                    if punto.get("inicio") < i < punto.get("fin"):
                        punto["detectado"] = True
                        flag = False
                        break

                for punto in drifts["drift_recurrente"]:
                    if i < punto.get("inicio"):
                        punto["detectado"] = True
                    if punto.get("inicio") < i < punto.get("fin"):
                        punto["detectado"] = True
                        flag = False
                        break

                # Clasificar como falsa alarma o detección válida
                if flag:
                    falsas_alarmas.append(i)
                else:
                    puntos_detectados.append(i)

                break  # Salir tras la primera detección para no seguir escaneando

    return (puntos_detectados, falsas_alarmas)

# %% [markdown]
# ### Cálculo de métricas y estadísticas. Escritura de archivo con resultados.

# %%
# ----------------------------------------------------------
# Función para guardar estadísticas de rendimiento de detección de 'concept drift'
# ----------------------------------------------------------
def guardar_estadisticas(detector, tipo_drift, distribucion, drifts, puntos_detectados, falsas_alarmas, tiempo_ejecucion):
    """
    Calcula y guarda las métricas de evaluación de la detección de 'concept drift' en un archivo Excel.

    Métricas calculadas:
    - FDR (False Discovery Rate): proporción de falsas alarmas sobre el total de detecciones (FP / (FP + TP)).
    - MDR (Missed Detection Rate): proporción de drifts no detectados (FN / (FN + TP)).
    - Tiempo de ejecución.

    Parámetros:
    - detector (str): nombre del detector utilizado (será el nombre de la hoja Excel).
    - tipo_drift (str): tipo de drift simulado (e.g. 'abrupt', 'gradual').
    - distribucion (str): tipo de distribución utilizada ('normal', 'gamma', etc.).
    - drifts (dict): estructura que contiene los drifts simulados y si fueron detectados.
    - puntos_detectados (list[int]): índices donde se detectó correctamente un drift.
    - falsas_alarmas (list[int]): índices de detecciones falsas (no pertenecen a zonas con drift).
    - tiempo_ejecucion (float): duración del experimento en segundos.
    - nombre_archivo (str): ruta al archivo Excel donde se guardarán las métricas.

    Retorna:
    - No retorna nada. Escribe los resultados en un archivo Excel.
    """

    print(f"Número de falsas alarmas: {len(falsas_alarmas)}")

    # Cálculo de FDR (False Discovery Rate): FP / (FP + TP)
    totales = len(puntos_detectados) + len(falsas_alarmas)
    if totales != 0:
        FDR = round(len(falsas_alarmas) / totales, 5)
        print(f"FDR: {FDR}")
    else:
        FDR = None

    # Cálculo de MDR (Missed Detection Rate): FN / (FN + TP)
    FN = 0  # Falsos negativos: drifts reales no detectados
    TP = 0  # Verdaderos positivos: drifts reales correctamente detectados
    for drift in drifts:
        for dr in drift:
            for punto in drift[dr]:
                if not punto["detectado"]:
                    print(f"Drift {dr} en el punto {punto} no detectado")
                    FN += 1
                else:
                    TP += 1

    MDR = round(FN / (FN + TP), 5) if (FN + TP) > 0 else None
    print(f"MDR: {MDR}")
    print(f"Tiempo de ejecución: {tiempo_ejecucion:.3f} segundos")

    # Crear DataFrame con los resultados
    df = pd.DataFrame([{
        "tipo_drift": tipo_drift,
        "distribucion": distribucion,
        "FDR": FDR,
        "MDR": MDR,
        "tiempo_ejecucion": tiempo_ejecucion
    }])

    nombre_archivo = "estadisticas_KSWINMod(config1y2)_Distribucion_Continua.xlsx"
    # Guardar en archivo Excel, actualizando hoja del detector si ya existe
    with excel_lock:
        try:
            with pd.ExcelFile(nombre_archivo) as xls:
                if detector in xls.sheet_names:
                    df_aux = pd.read_excel(xls, sheet_name=detector)
                    matching_rows = df_aux[
                        (df_aux["tipo_drift"] == df["tipo_drift"].iloc[0]) &
                        (df_aux["distribucion"] == df["distribucion"].iloc[0])
                    ]
                    if not matching_rows.empty:
                        index_existente = matching_rows.index[0]
                        df_aux.iloc[index_existente] = df.iloc[0]
                    else:
                        df_aux = pd.concat([df_aux, df], ignore_index=True)

                    with pd.ExcelWriter(nombre_archivo, engine='openpyxl', mode='a') as writer:
                        writer.book.remove(writer.book[detector])
                        df_aux.to_excel(writer, sheet_name=detector, index=False)
                else:
                    with pd.ExcelWriter(nombre_archivo, engine='openpyxl', mode='a') as writer:
                        df.to_excel(writer, sheet_name=detector, index=False)

        except FileNotFoundError:
            with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:
                df.to_excel(writer, sheet_name=detector, index=False)

        except Exception as e:
            print(f"Error general: {e}")

# %% [markdown]
# ## KSWIN configuración original

# %% [markdown]
# ### Abrupt drift

# %% [markdown]
# #### Distribución normal

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.1, distribucion="normal")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, None , drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15062

# %%
guardar_estadisticas("KSWIN", "abrupto", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribución exponencial

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.1, distribucion="exponential")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15092

# %%
guardar_estadisticas("KSWIN", "abrupto", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 0
# FAR: 0.0
# MDR: 0.0
# Tiempo de ejecucion: 13.20808744430542

# %% [markdown]
# #### Distribucion gamma

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.1, distribucion="gamma")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15180

# %%
guardar_estadisticas("KSWIN", "abrupto", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 0
# FAR: 0.0
# MDR: 0.0
# Tiempo de ejecucion: 13.493180751800537

# %% [markdown]
# ### Incremental drift

# %% [markdown]
# #### Distribucion normal

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.1, distribucion="normal")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 9617
# Drift detectado en el índice 15234
# Drift detectado en el índice 9497
# Drift detectado en el índice 12274
# Drift detectado en el índice 15301
# Drift detectado en el índice 15343
# Drift detectado en el índice 16373
# Drift detectado en el índice 15234
# Drift detectado en el índice 5905
# Drift detectado en el índice 16317
# Drift detectado en el índice 17000
# Drift detectado en el índice 4442
# Drift detectado en el índice 14528
# Drift detectado en el índice 15290
# Drift detectado en el índice 10374
# Drift detectado en el índice 7444
# Drift detectado en el índice 8880
# Drift detectado en el índice 4826
# Drift detectado en el índice 3224
# Drift detectado en el índice 17180
# Drift detectado en el índice 12691
# Drift detectado en el índice 15190
# Drift detectado en el índice 15371
# Drift detectado en el índice 15271
# Drift detectado en el índice 13890
# Drift detectado en el índice 15264
# Drift detectado en el índice 3592
# Drift detectado en el índice 14949
# Drift detectado en el índice 15134
# Drift detectado en el índice 15311
# Drift detectado en el índice 15482
# Drift detectado en el índice 3999
# Drift detectado en el índice 15575
# Drift detectado en el índice 6033
# Drift detectado en el índice 6256
# Drift detectado en el índice 15702
# Drift detectado en el índice 15565
# Drift detectado en el índice 12004
# Drift detectado en el índice 9715
# Drift detectado en el índice 8761
# Drift detectado en el índice 5252
# Drift detectado en el índice 11406
# Drift detectado en el índice 3681
# Drift detectado en el índice 15626
# Drift detectado en el índice 15262
# Drift detectado en el índice 9262
# Drift detectado en el índice 7416
# Drift detectado en el índice 6379
# Drift detectado en el índice 5709
# Drift detectado en el índice 14549
# Drift detectado en el índice 15442
# Drift detectado en el índice 9434
# Drift detectado en el índice 16716
# Drift detectado en el índice 11535
# Drift detectado en el índice 9841
# Drift detectado en el índice 18001
# Drift detectado en el índice 15484
# Drift detectado en el índice 3952
# Drift detectado en el índice 15402
# Drift detectado en el índice 15286
# Drift detectado en el índice 15391
# Drift detectado en el índice 6355
# Drift detectado en el índice 3224
# Drift detectado en el índice 15321
# Drift detectado en el índice 15761
# Drift detectado en el índice 9722
# Drift detectado en el índice 15196
# Drift detectado en el índice 15448
# Drift detectado en el índice 9536
# Drift detectado en el índice 15609
# Drift detectado en el índice 12267
# Drift detectado en el índice 15272
# Drift detectado en el índice 8436
# Drift detectado en el índice 12687
# Drift detectado en el índice 3494
# Drift detectado en el índice 15643
# Drift detectado en el índice 15829
# Drift detectado en el índice 15286
# Drift detectado en el índice 15568
# Drift detectado en el índice 10583
# Drift detectado en el índice 15157
# Drift detectado en el índice 15187
# Drift detectado en el índice 15257
# Drift detectado en el índice 15423
# Drift detectado en el índice 15398
# Drift detectado en el índice 9891
# Drift detectado en el índice 11131
# Drift detectado en el índice 15959
# Drift detectado en el índice 12000
# Drift detectado en el índice 16373
# Drift detectado en el índice 15252
# Drift detectado en el índice 15657
# Drift detectado en el índice 5596
# Drift detectado en el índice 15390
# Drift detectado en el índice 15181
# Drift detectado en el índice 15254
# Drift detectado en el índice 13709
# Drift detectado en el índice 5667
# Drift detectado en el índice 7808
# Drift detectado en el índice 14329
# Drift detectado en el índice 7722
# Drift detectado en el índice 15910
# Drift detectado en el índice 4711
# Drift detectado en el índice 15314
# Drift detectado en el índice 15294
# Drift detectado en el índice 16523
# Drift detectado en el índice 15378
# Drift detectado en el índice 15571
# Drift detectado en el índice 6727
# Drift detectado en el índice 15230
# Drift detectado en el índice 14640
# Drift detectado en el índice 15463
# Drift detectado en el índice 15584
# Drift detectado en el índice 7858
# Drift detectado en el índice 15589
# Drift detectado en el índice 15491
# Drift detectado en el índice 15196
# Drift detectado en el índice 5667
# Drift detectado en el índice 3727
# Drift detectado en el índice 15547
# Drift detectado en el índice 8636
# Drift detectado en el índice 5487
# Drift detectado en el índice 8330
# Drift detectado en el índice 15544
# Drift detectado en el índice 15428
# Drift detectado en el índice 5822
# Drift detectado en el índice 4835
# Drift detectado en el índice 7937
# Drift detectado en el índice 7023
# Drift detectado en el índice 9191
# Drift detectado en el índice 11222
# Drift detectado en el índice 7846
# Drift detectado en el índice 9214
# Drift detectado en el índice 3771
# Drift detectado en el índice 14038
# Drift detectado en el índice 12889
# Drift detectado en el índice 15395
# Drift detectado en el índice 15325
# Drift detectado en el índice 14517
# Drift detectado en el índice 16608
# Drift detectado en el índice 5337
# Drift detectado en el índice 11076
# Drift detectado en el índice 8090
# Drift detectado en el índice 15490
# Drift detectado en el índice 16068
# Drift detectado en el índice 4351
# Drift detectado en el índice 16314
# Drift detectado en el índice 15577
# Drift detectado en el índice 15520
# Drift detectado en el índice 11833
# Drift detectado en el índice 15361
# Drift detectado en el índice 11692
# Drift detectado en el índice 16093
# Drift detectado en el índice 15448
# Drift detectado en el índice 4136
# Drift detectado en el índice 15766
# Drift detectado en el índice 16603
# Drift detectado en el índice 15343
# Drift detectado en el índice 16021
# Drift detectado en el índice 7436
# Drift detectado en el índice 3900
# Drift detectado en el índice 17094
# Drift detectado en el índice 9049
# Drift detectado en el índice 15760
# Drift detectado en el índice 5515
# Drift detectado en el índice 4174
# Drift detectado en el índice 6014
# Drift detectado en el índice 6819
# Drift detectado en el índice 9598
# Drift detectado en el índice 15391
# Drift detectado en el índice 12117
# Drift detectado en el índice 12893
# Drift detectado en el índice 4965
# Drift detectado en el índice 15476
# Drift detectado en el índice 15427
# Drift detectado en el índice 3391
# Drift detectado en el índice 4188
# Drift detectado en el índice 15326
# Drift detectado en el índice 15323
# Drift detectado en el índice 15417
# Drift detectado en el índice 7925
# Drift detectado en el índice 15544
# Drift detectado en el índice 18610
# Drift detectado en el índice 4823
# Drift detectado en el índice 13089
# Drift detectado en el índice 4164
# Drift detectado en el índice 15323
# Drift detectado en el índice 15667
# Drift detectado en el índice 6973
# Drift detectado en el índice 15349
# Drift detectado en el índice 14602
# Drift detectado en el índice 4246
# Drift detectado en el índice 11507
# Drift detectado en el índice 7739
# Drift detectado en el índice 3312
# Drift detectado en el índice 15589
# Drift detectado en el índice 15600
# Drift detectado en el índice 7206
# Drift detectado en el índice 6017
# Drift detectado en el índice 15405
# Drift detectado en el índice 15991
# Drift detectado en el índice 15358
# Drift detectado en el índice 13762
# Drift detectado en el índice 15209
# Drift detectado en el índice 15310
# Drift detectado en el índice 15324
# Drift detectado en el índice 14950
# Drift detectado en el índice 9644
# Drift detectado en el índice 11381
# Drift detectado en el índice 15271
# Drift detectado en el índice 15198
# Drift detectado en el índice 15249
# Drift detectado en el índice 15165
# Drift detectado en el índice 15962
# Drift detectado en el índice 5700
# Drift detectado en el índice 3184
# Drift detectado en el índice 15743
# Drift detectado en el índice 15338
# Drift detectado en el índice 17776
# Drift detectado en el índice 3498
# Drift detectado en el índice 10305
# Drift detectado en el índice 15264
# Drift detectado en el índice 15248
# Drift detectado en el índice 4016
# Drift detectado en el índice 4746
# Drift detectado en el índice 15352
# Drift detectado en el índice 11994
# Drift detectado en el índice 12278
# Drift detectado en el índice 15338
# Drift detectado en el índice 15604
# Drift detectado en el índice 3798
# Drift detectado en el índice 14157
# Drift detectado en el índice 11058
# Drift detectado en el índice 15353
# Drift detectado en el índice 15430
# Drift detectado en el índice 9844
# Drift detectado en el índice 16090
# Drift detectado en el índice 7897
# Drift detectado en el índice 13283
# Drift detectado en el índice 15676
# Drift detectado en el índice 11048
# Drift detectado en el índice 15220
# Drift detectado en el índice 15373
# Drift detectado en el índice 15328
# Drift detectado en el índice 15335
# Drift detectado en el índice 15262
# Drift detectado en el índice 16072
# Drift detectado en el índice 11059
# Drift detectado en el índice 3149
# Drift detectado en el índice 15401
# Drift detectado en el índice 8316
# Drift detectado en el índice 13685
# Drift detectado en el índice 15252
# Drift detectado en el índice 6995
# Drift detectado en el índice 15480
# Drift detectado en el índice 13707
# Drift detectado en el índice 4152
# Drift detectado en el índice 15343
# Drift detectado en el índice 9852
# Drift detectado en el índice 8374
# Drift detectado en el índice 15366
# Drift detectado en el índice 14891
# Drift detectado en el índice 12510
# Drift detectado en el índice 7749
# Drift detectado en el índice 15273
# Drift detectado en el índice 8508
# Drift detectado en el índice 4356
# Drift detectado en el índice 15523
# Drift detectado en el índice 15494
# Drift detectado en el índice 15146
# Drift detectado en el índice 15790
# Drift detectado en el índice 10024
# Drift detectado en el índice 16481
# Drift detectado en el índice 15785
# Drift detectado en el índice 15176
# Drift detectado en el índice 15343
# Drift detectado en el índice 15350
# Drift detectado en el índice 13410
# Drift detectado en el índice 5904
# Drift detectado en el índice 5286
# Drift detectado en el índice 13849
# Drift detectado en el índice 15803
# Drift detectado en el índice 6264
# Drift detectado en el índice 3170
# Drift detectado en el índice 10740
# Drift detectado en el índice 15435
# Drift detectado en el índice 15436
# Drift detectado en el índice 3553
# Drift detectado en el índice 15253
# Drift detectado en el índice 15327
# Drift detectado en el índice 6593
# Drift detectado en el índice 4063
# Drift detectado en el índice 3352
# Drift detectado en el índice 11343
# Drift detectado en el índice 16344
# Drift detectado en el índice 8332
# Drift detectado en el índice 15777
# Drift detectado en el índice 13203
# Drift detectado en el índice 15551
# Drift detectado en el índice 8425
# Drift detectado en el índice 5859
# Drift detectado en el índice 15233
# Drift detectado en el índice 7038
# Drift detectado en el índice 7623
# Drift detectado en el índice 7574
# Drift detectado en el índice 15872
# Drift detectado en el índice 8143
# Drift detectado en el índice 15160
# Drift detectado en el índice 5122
# Drift detectado en el índice 15183
# Drift detectado en el índice 14469
# Drift detectado en el índice 15492
# Drift detectado en el índice 14206
# Drift detectado en el índice 10812
# Drift detectado en el índice 16992
# Drift detectado en el índice 11494
# Drift detectado en el índice 12073
# Drift detectado en el índice 15231
# Drift detectado en el índice 16204
# Drift detectado en el índice 8380
# Drift detectado en el índice 4544
# Drift detectado en el índice 5581
# Drift detectado en el índice 15460
# Drift detectado en el índice 15281
# Drift detectado en el índice 7699
# Drift detectado en el índice 8977
# Drift detectado en el índice 13191
# Drift detectado en el índice 11458
# Drift detectado en el índice 15447
# Drift detectado en el índice 15245
# Drift detectado en el índice 3763
# Drift detectado en el índice 4071
# Drift detectado en el índice 15201
# Drift detectado en el índice 15286
# Drift detectado en el índice 8630
# Drift detectado en el índice 15333
# Drift detectado en el índice 8662
# Drift detectado en el índice 16017
# Drift detectado en el índice 15319
# Drift detectado en el índice 5453
# Drift detectado en el índice 11120
# Drift detectado en el índice 15417
# Drift detectado en el índice 15223
# Drift detectado en el índice 13788
# Drift detectado en el índice 23116
# Drift detectado en el índice 3118
# Drift detectado en el índice 6523
# Drift detectado en el índice 15297
# Drift detectado en el índice 15306
# Drift detectado en el índice 15440
# Drift detectado en el índice 7682
# Drift detectado en el índice 14935
# Drift detectado en el índice 9314
# Drift detectado en el índice 15255
# Drift detectado en el índice 11751
# Drift detectado en el índice 12325
# Drift detectado en el índice 14942
# Drift detectado en el índice 15325
# Drift detectado en el índice 4579
# Drift detectado en el índice 16574
# Drift detectado en el índice 5205
# Drift detectado en el índice 15268
# Drift detectado en el índice 15262
# Drift detectado en el índice 14218
# Drift detectado en el índice 4541
# Drift detectado en el índice 4361
# Drift detectado en el índice 5458
# Drift detectado en el índice 3868
# Drift detectado en el índice 15561
# Drift detectado en el índice 15540
# Drift detectado en el índice 4607
# Drift detectado en el índice 14032
# Drift detectado en el índice 15464
# Drift detectado en el índice 15330
# Drift detectado en el índice 12423
# Drift detectado en el índice 15396
# Drift detectado en el índice 15217
# Drift detectado en el índice 10786
# Drift detectado en el índice 15856
# Drift detectado en el índice 6428
# Drift detectado en el índice 15492
# Drift detectado en el índice 15425
# Drift detectado en el índice 15344
# Drift detectado en el índice 11028
# Drift detectado en el índice 10982
# Drift detectado en el índice 11990
# Drift detectado en el índice 16353
# Drift detectado en el índice 15559
# Drift detectado en el índice 16215
# Drift detectado en el índice 16810
# Drift detectado en el índice 10455
# Drift detectado en el índice 7457
# Drift detectado en el índice 15373
# Drift detectado en el índice 15420
# Drift detectado en el índice 14982
# Drift detectado en el índice 9713
# Drift detectado en el índice 15203
# Drift detectado en el índice 3181
# Drift detectado en el índice 5590
# Drift detectado en el índice 15323
# Drift detectado en el índice 10902
# Drift detectado en el índice 5008
# Drift detectado en el índice 16154
# Drift detectado en el índice 10701
# Drift detectado en el índice 3894
# Drift detectado en el índice 3164
# Drift detectado en el índice 15342
# Drift detectado en el índice 7271
# Drift detectado en el índice 15347
# Drift detectado en el índice 15439
# Drift detectado en el índice 15212
# Drift detectado en el índice 15912
# Drift detectado en el índice 15630
# Drift detectado en el índice 10644
# Drift detectado en el índice 10676
# Drift detectado en el índice 14565
# Drift detectado en el índice 6942
# Drift detectado en el índice 15284
# Drift detectado en el índice 9345
# Drift detectado en el índice 18682
# Drift detectado en el índice 15337
# Drift detectado en el índice 5591
# Drift detectado en el índice 16132
# Drift detectado en el índice 15801
# Drift detectado en el índice 4766
# Drift detectado en el índice 11848
# Drift detectado en el índice 5507
# Drift detectado en el índice 10444
# Drift detectado en el índice 15393
# Drift detectado en el índice 15128
# Drift detectado en el índice 7562
# Drift detectado en el índice 15714
# Drift detectado en el índice 14666
# Drift detectado en el índice 11961
# Drift detectado en el índice 16258
# Drift detectado en el índice 15550
# Drift detectado en el índice 15283
# Drift detectado en el índice 15446
# Drift detectado en el índice 15651
# Drift detectado en el índice 15236
# Drift detectado en el índice 15421
# Drift detectado en el índice 14002
# Drift detectado en el índice 15369
# Drift detectado en el índice 17330
# Drift detectado en el índice 15570
# Drift detectado en el índice 5660
# Drift detectado en el índice 15428
# Drift detectado en el índice 15272
# Drift detectado en el índice 10481
# Drift detectado en el índice 13942
# Drift detectado en el índice 7607
# Drift detectado en el índice 16728
# Drift detectado en el índice 15564
# Drift detectado en el índice 11714
# Drift detectado en el índice 15382
# Drift detectado en el índice 15586
# Drift detectado en el índice 9402
# Drift detectado en el índice 15385
# Drift detectado en el índice 15361
# Drift detectado en el índice 15362
# Drift detectado en el índice 3227
# Drift detectado en el índice 5192
# Drift detectado en el índice 15295
# Drift detectado en el índice 15329
# Drift detectado en el índice 15358
# Drift detectado en el índice 15488
# Drift detectado en el índice 15251
# Drift detectado en el índice 13542
# Drift detectado en el índice 15411
# Drift detectado en el índice 12660
# Drift detectado en el índice 15343
# Drift detectado en el índice 3685
# Drift detectado en el índice 15236
# Drift detectado en el índice 15225
# Drift detectado en el índice 10113
# Drift detectado en el índice 4170
# Drift detectado en el índice 10885
# Drift detectado en el índice 9784
# Drift detectado en el índice 10700
# Drift detectado en el índice 4540
# Drift detectado en el índice 15566
# Drift detectado en el índice 15417
# Drift detectado en el índice 13229
# Drift detectado en el índice 7301
# Drift detectado en el índice 15371
# Drift detectado en el índice 15400
# Drift detectado en el índice 14762
# Drift detectado en el índice 7192
# Drift detectado en el índice 9682
# Drift detectado en el índice 13465
# Drift detectado en el índice 15370
# Drift detectado en el índice 15515
# Drift detectado en el índice 7079
# Drift detectado en el índice 13903
# Drift detectado en el índice 4517
# Drift detectado en el índice 5423
# Drift detectado en el índice 15719
# Drift detectado en el índice 15365
# Drift detectado en el índice 15238
# Drift detectado en el índice 15319
# Drift detectado en el índice 15268
# Drift detectado en el índice 15707
# Drift detectado en el índice 15381
# Drift detectado en el índice 4529
# Drift detectado en el índice 4656
# Drift detectado en el índice 15260
# Drift detectado en el índice 8122
# Drift detectado en el índice 10784
# Drift detectado en el índice 16281
# Drift detectado en el índice 14628
# Drift detectado en el índice 15543
# Drift detectado en el índice 7579
# Drift detectado en el índice 3779
# Drift detectado en el índice 17267
# Drift detectado en el índice 9699
# Drift detectado en el índice 15272
# Drift detectado en el índice 9907
# Drift detectado en el índice 15276
# Drift detectado en el índice 15292
# Drift detectado en el índice 5999
# Drift detectado en el índice 4290
# Drift detectado en el índice 15689
# Drift detectado en el índice 15747
# Drift detectado en el índice 8340
# Drift detectado en el índice 11672
# Drift detectado en el índice 10885
# Drift detectado en el índice 6065
# Drift detectado en el índice 5679
# Drift detectado en el índice 15300
# Drift detectado en el índice 4557
# Drift detectado en el índice 4442
# Drift detectado en el índice 6989
# Drift detectado en el índice 15329
# Drift detectado en el índice 15289
# Drift detectado en el índice 15785
# Drift detectado en el índice 15786
# Drift detectado en el índice 15195
# Drift detectado en el índice 15575
# Drift detectado en el índice 8716
# Drift detectado en el índice 10796
# Drift detectado en el índice 15266
# Drift detectado en el índice 11356
# Drift detectado en el índice 15748
# Drift detectado en el índice 16255
# Drift detectado en el índice 15188
# Drift detectado en el índice 9366
# Drift detectado en el índice 12171
# Drift detectado en el índice 15454
# Drift detectado en el índice 13578
# Drift detectado en el índice 11417
# Drift detectado en el índice 14143
# Drift detectado en el índice 15276
# Drift detectado en el índice 15287
# Drift detectado en el índice 9467
# Drift detectado en el índice 11916
# Drift detectado en el índice 19610
# Drift detectado en el índice 13841
# Drift detectado en el índice 8877
# Drift detectado en el índice 10260
# Drift detectado en el índice 14002
# Drift detectado en el índice 15585
# Drift detectado en el índice 11345
# Drift detectado en el índice 15453
# Drift detectado en el índice 10555
# Drift detectado en el índice 15933
# Drift detectado en el índice 15787
# Drift detectado en el índice 11972
# Drift detectado en el índice 16596
# Drift detectado en el índice 14759
# Drift detectado en el índice 3999
# Drift detectado en el índice 15548
# Drift detectado en el índice 15219
# Drift detectado en el índice 15405
# Drift detectado en el índice 15387
# Drift detectado en el índice 12161
# Drift detectado en el índice 6741
# Drift detectado en el índice 15320
# Drift detectado en el índice 15343
# Drift detectado en el índice 15342
# Drift detectado en el índice 11449
# Drift detectado en el índice 15198
# Drift detectado en el índice 7148
# Drift detectado en el índice 15197
# Drift detectado en el índice 5842
# Drift detectado en el índice 15204
# Drift detectado en el índice 15413
# Drift detectado en el índice 12238
# Drift detectado en el índice 4824
# Drift detectado en el índice 6066
# Drift detectado en el índice 6406
# Drift detectado en el índice 15673
# Drift detectado en el índice 3154
# Drift detectado en el índice 15473
# Drift detectado en el índice 16312
# Drift detectado en el índice 3496
# Drift detectado en el índice 6886
# Drift detectado en el índice 15485
# Drift detectado en el índice 3709
# Drift detectado en el índice 3069
# Drift detectado en el índice 15457
# Drift detectado en el índice 15599
# Drift detectado en el índice 14555
# Drift detectado en el índice 9470
# Drift detectado en el índice 15239
# Drift detectado en el índice 5126
# Drift detectado en el índice 4519
# Drift detectado en el índice 15708
# Drift detectado en el índice 17778
# Drift detectado en el índice 15256
# Drift detectado en el índice 9386
# Drift detectado en el índice 15307
# Drift detectado en el índice 15172
# Drift detectado en el índice 7295
# Drift detectado en el índice 11505
# Drift detectado en el índice 11778
# Drift detectado en el índice 4131
# Drift detectado en el índice 5357
# Drift detectado en el índice 15379
# Drift detectado en el índice 4409
# Drift detectado en el índice 15472
# Drift detectado en el índice 11939
# Drift detectado en el índice 6832
# Drift detectado en el índice 15420
# Drift detectado en el índice 10545
# Drift detectado en el índice 12437
# Drift detectado en el índice 4201
# Drift detectado en el índice 3257
# Drift detectado en el índice 15243
# Drift detectado en el índice 4209
# Drift detectado en el índice 15364
# Drift detectado en el índice 24378
# Drift detectado en el índice 8828
# Drift detectado en el índice 15420
# Drift detectado en el índice 3767
# Drift detectado en el índice 10616
# Drift detectado en el índice 15239
# Drift detectado en el índice 4154
# Drift detectado en el índice 15573
# Drift detectado en el índice 15434
# Drift detectado en el índice 16316
# Drift detectado en el índice 11899
# Drift detectado en el índice 13609
# Drift detectado en el índice 9274
# Drift detectado en el índice 9806
# Drift detectado en el índice 16061
# Drift detectado en el índice 5440
# Drift detectado en el índice 5726
# Drift detectado en el índice 15378
# Drift detectado en el índice 15343
# Drift detectado en el índice 15891
# Drift detectado en el índice 15638
# Drift detectado en el índice 13706
# Drift detectado en el índice 6020
# Drift detectado en el índice 15335
# Drift detectado en el índice 9967
# Drift detectado en el índice 15262
# Drift detectado en el índice 15708
# Drift detectado en el índice 9207
# Drift detectado en el índice 7059
# Drift detectado en el índice 9584
# Drift detectado en el índice 15561
# Drift detectado en el índice 15315
# Drift detectado en el índice 16969
# Drift detectado en el índice 15302
# Drift detectado en el índice 7407
# Drift detectado en el índice 15260
# Drift detectado en el índice 15247
# Drift detectado en el índice 16165
# Drift detectado en el índice 15802
# Drift detectado en el índice 15385
# Drift detectado en el índice 15247
# Drift detectado en el índice 13324
# Drift detectado en el índice 3841
# Drift detectado en el índice 15412
# Drift detectado en el índice 18757
# Drift detectado en el índice 15336
# Drift detectado en el índice 15680
# Drift detectado en el índice 15428
# Drift detectado en el índice 15796
# Drift detectado en el índice 7806
# Drift detectado en el índice 7656
# Drift detectado en el índice 15353
# Drift detectado en el índice 15870
# Drift detectado en el índice 15154
# Drift detectado en el índice 15436
# Drift detectado en el índice 17287
# Drift detectado en el índice 15348
# Drift detectado en el índice 10176
# Drift detectado en el índice 6470
# Drift detectado en el índice 4373
# Drift detectado en el índice 12136
# Drift detectado en el índice 6931
# Drift detectado en el índice 12502
# Drift detectado en el índice 15090
# Drift detectado en el índice 15304
# Drift detectado en el índice 5631
# Drift detectado en el índice 12087
# Drift detectado en el índice 15344
# Drift detectado en el índice 8491
# Drift detectado en el índice 13152
# Drift detectado en el índice 15409
# Drift detectado en el índice 5178
# Drift detectado en el índice 16211
# Drift detectado en el índice 10790
# Drift detectado en el índice 6124
# Drift detectado en el índice 11276
# Drift detectado en el índice 15369
# Drift detectado en el índice 5261
# Drift detectado en el índice 16042
# Drift detectado en el índice 15149
# Drift detectado en el índice 9650
# Drift detectado en el índice 3449
# Drift detectado en el índice 6417
# Drift detectado en el índice 15992
# Drift detectado en el índice 15496
# Drift detectado en el índice 15435
# Drift detectado en el índice 15226
# Drift detectado en el índice 8059
# Drift detectado en el índice 15351
# Drift detectado en el índice 9746
# Drift detectado en el índice 12063
# Drift detectado en el índice 4320
# Drift detectado en el índice 12610
# Drift detectado en el índice 11089
# Drift detectado en el índice 15352
# Drift detectado en el índice 13988
# Drift detectado en el índice 15322
# Drift detectado en el índice 15917
# Drift detectado en el índice 8444
# Drift detectado en el índice 15632
# Drift detectado en el índice 15409
# Drift detectado en el índice 15491
# Drift detectado en el índice 15379
# Drift detectado en el índice 9635
# Drift detectado en el índice 11828
# Drift detectado en el índice 10382
# Drift detectado en el índice 8266
# Drift detectado en el índice 15170
# Drift detectado en el índice 15286
# Drift detectado en el índice 15269
# Drift detectado en el índice 16633
# Drift detectado en el índice 15525
# Drift detectado en el índice 7859
# Drift detectado en el índice 5797
# Drift detectado en el índice 7787
# Drift detectado en el índice 3440
# Drift detectado en el índice 7196
# Drift detectado en el índice 15436
# Drift detectado en el índice 15593
# Drift detectado en el índice 3243
# Drift detectado en el índice 10150
# Drift detectado en el índice 3651
# Drift detectado en el índice 4563
# Drift detectado en el índice 10504
# Drift detectado en el índice 15415
# Drift detectado en el índice 14181
# Drift detectado en el índice 4861
# Drift detectado en el índice 7157
# Drift detectado en el índice 8190
# Drift detectado en el índice 15290
# Drift detectado en el índice 15283
# Drift detectado en el índice 15853
# Drift detectado en el índice 10117
# Drift detectado en el índice 7890
# Drift detectado en el índice 15699
# Drift detectado en el índice 15364
# Drift detectado en el índice 4294
# Drift detectado en el índice 15629
# Drift detectado en el índice 16834
# Drift detectado en el índice 15329
# Drift detectado en el índice 15243
# Drift detectado en el índice 15197
# Drift detectado en el índice 3957
# Drift detectado en el índice 17400
# Drift detectado en el índice 15604
# Drift detectado en el índice 7220
# Drift detectado en el índice 15478
# Drift detectado en el índice 3289
# Drift detectado en el índice 7829
# Drift detectado en el índice 16656
# Drift detectado en el índice 3513
# Drift detectado en el índice 13201
# Drift detectado en el índice 9470
# Drift detectado en el índice 15315
# Drift detectado en el índice 15252
# Drift detectado en el índice 9466
# Drift detectado en el índice 6489
# Drift detectado en el índice 15448
# Drift detectado en el índice 15405
# Drift detectado en el índice 15365
# Drift detectado en el índice 15228
# Drift detectado en el índice 15370
# Drift detectado en el índice 8785
# Drift detectado en el índice 14790
# Drift detectado en el índice 6216
# Drift detectado en el índice 3758
# Drift detectado en el índice 15483
# Drift detectado en el índice 15329
# Drift detectado en el índice 6787
# Drift detectado en el índice 15695
# Drift detectado en el índice 17247
# Drift detectado en el índice 5461
# Drift detectado en el índice 15394
# Drift detectado en el índice 8755
# Drift detectado en el índice 15499
# Drift detectado en el índice 9180
# Drift detectado en el índice 11617
# Drift detectado en el índice 15315
# Drift detectado en el índice 15434
# Drift detectado en el índice 5138
# Drift detectado en el índice 9882
# Drift detectado en el índice 11166
# Drift detectado en el índice 15609
# Drift detectado en el índice 7647
# Drift detectado en el índice 5681
# Drift detectado en el índice 4017
# Drift detectado en el índice 11624
# Drift detectado en el índice 12945
# Drift detectado en el índice 15393
# Drift detectado en el índice 7199
# Drift detectado en el índice 11932
# Drift detectado en el índice 15383
# Drift detectado en el índice 15379
# Drift detectado en el índice 15295
# Drift detectado en el índice 15486
# Drift detectado en el índice 15388
# Drift detectado en el índice 9745
# Drift detectado en el índice 4436
# Drift detectado en el índice 15474
# Drift detectado en el índice 15626
# Drift detectado en el índice 13864
# Drift detectado en el índice 8286
# Drift detectado en el índice 13990
# Drift detectado en el índice 15230
# Drift detectado en el índice 15491
# Drift detectado en el índice 15703
# Drift detectado en el índice 4530
# Drift detectado en el índice 15420
# Drift detectado en el índice 15392
# Drift detectado en el índice 15452
# Drift detectado en el índice 8327
# Drift detectado en el índice 13715
# Drift detectado en el índice 15228
# Drift detectado en el índice 3681
# Drift detectado en el índice 15046
# Drift detectado en el índice 15919
# Drift detectado en el índice 14068
# Drift detectado en el índice 4239
# Drift detectado en el índice 16489
# Drift detectado en el índice 10370
# Drift detectado en el índice 15213
# Drift detectado en el índice 15430
# Drift detectado en el índice 14376
# Drift detectado en el índice 3640
# Drift detectado en el índice 15181
# Drift detectado en el índice 15327
# Drift detectado en el índice 15438
# Drift detectado en el índice 6092
# Drift detectado en el índice 5083
# Drift detectado en el índice 7326
# Drift detectado en el índice 14545
# Drift detectado en el índice 3999
# Drift detectado en el índice 4540
# Drift detectado en el índice 15404
# Drift detectado en el índice 9442
# Drift detectado en el índice 15322
# Drift detectado en el índice 15737
# Drift detectado en el índice 15848
# Drift detectado en el índice 8438
# Drift detectado en el índice 15281
# Drift detectado en el índice 4071
# Drift detectado en el índice 15211
# Drift detectado en el índice 15241
# Drift detectado en el índice 15705
# Drift detectado en el índice 15192
# Drift detectado en el índice 8672
# Drift detectado en el índice 3844
# Drift detectado en el índice 16013
# Drift detectado en el índice 15076
# Drift detectado en el índice 7348
# Drift detectado en el índice 15905
# Drift detectado en el índice 5701
# Drift detectado en el índice 14788
# Drift detectado en el índice 28184
# Drift detectado en el índice 5227
# Drift detectado en el índice 15590
# Drift detectado en el índice 15883
# Drift detectado en el índice 16751
# Drift detectado en el índice 3658
# Drift detectado en el índice 3511
# Drift detectado en el índice 15195
# Drift detectado en el índice 5167
# Drift detectado en el índice 8229
# Drift detectado en el índice 15836
# Drift detectado en el índice 15359
# Drift detectado en el índice 15405
# Drift detectado en el índice 11792
# Drift detectado en el índice 15481
# Drift detectado en el índice 4851
# Drift detectado en el índice 15283
# Drift detectado en el índice 15622
# Drift detectado en el índice 15226
# Drift detectado en el índice 6839
# Drift detectado en el índice 15827
# Drift detectado en el índice 8898
# Drift detectado en el índice 11710
# Drift detectado en el índice 8948
# Drift detectado en el índice 15227
# Drift detectado en el índice 15822
# Drift detectado en el índice 15186
# Drift detectado en el índice 16953
# Drift detectado en el índice 5403
# Drift detectado en el índice 13346
# Drift detectado en el índice 15236
# Drift detectado en el índice 4768
# Drift detectado en el índice 4521
# Drift detectado en el índice 15377
# Drift detectado en el índice 6049
# Drift detectado en el índice 9915
# Drift detectado en el índice 14366
# Drift detectado en el índice 15550
# Drift detectado en el índice 13901
# Drift detectado en el índice 12969
# Drift detectado en el índice 15406
# Drift detectado en el índice 16007
# Drift detectado en el índice 16136
# Drift detectado en el índice 3385
# Drift detectado en el índice 3547
# Drift detectado en el índice 13154
# Drift detectado en el índice 15228
# Drift detectado en el índice 6211
# Drift detectado en el índice 11647
# Drift detectado en el índice 10199
# Drift detectado en el índice 15294
# Drift detectado en el índice 15459
# Drift detectado en el índice 15503
# Drift detectado en el índice 9540
# Drift detectado en el índice 15586
# Drift detectado en el índice 15341
# Drift detectado en el índice 15316
# Drift detectado en el índice 15344
# Drift detectado en el índice 13482
# Drift detectado en el índice 15475
# Drift detectado en el índice 12903
# Drift detectado en el índice 7242
# Drift detectado en el índice 9846
# Drift detectado en el índice 15347
# Drift detectado en el índice 8834
# Drift detectado en el índice 14834
# Drift detectado en el índice 11088
# Drift detectado en el índice 9110
# Drift detectado en el índice 15443
# Drift detectado en el índice 15271
# Drift detectado en el índice 4264
# Drift detectado en el índice 8773
# Drift detectado en el índice 15591
# Drift detectado en el índice 5683
# Drift detectado en el índice 12210
# Drift detectado en el índice 4944
# Drift detectado en el índice 4102
# Drift detectado en el índice 15515
# Drift detectado en el índice 15892
# Drift detectado en el índice 9158
# Drift detectado en el índice 8573
# Drift detectado en el índice 15399
# Drift detectado en el índice 8552
# Drift detectado en el índice 15282
# Drift detectado en el índice 8643
# Drift detectado en el índice 9142
# Drift detectado en el índice 4458
# Drift detectado en el índice 15245
# Drift detectado en el índice 15281
# Drift detectado en el índice 4980
# Drift detectado en el índice 15788
# Drift detectado en el índice 15267
# Drift detectado en el índice 15522
# Drift detectado en el índice 15398
# Drift detectado en el índice 15510
# Drift detectado en el índice 15453
# Drift detectado en el índice 5905
# Drift detectado en el índice 13637
# Drift detectado en el índice 7224
# Drift detectado en el índice 16951
# Drift detectado en el índice 8153
# Drift detectado en el índice 15579
# Drift detectado en el índice 15475
# Drift detectado en el índice 15317
# Drift detectado en el índice 11807
# Drift detectado en el índice 16171
# Drift detectado en el índice 15445
# Drift detectado en el índice 15313

# %%
guardar_estadisticas("KSWIN", "incremental", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 518
# FAR: 0.5227
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# MDR: 0.026
# Tiempo de ejecucion: 10008.264249801636

# %% [markdown]
# #### Distribucion exponencial

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.1, distribucion="exponential")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 9290

# %%
guardar_estadisticas("KSWIN", "incremental", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 1
# FAR: 1.0
# MDR: 0.0
# Tiempo de ejecucion: 7.368058919906616

# %% [markdown]
# #### Distribucion gamma

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.1, distribucion="gamma")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15087

# %%
guardar_estadisticas("KSWIN", "incremental", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 0
# FAR: 0.0
# MDR: 0.0
# Tiempo de ejecucion: 13.364972591400146

# %% [markdown]
# ### Gradual drift

# %% [markdown]
# #### Distribucion normal

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.1, distribucion="normal")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15394
# Drift detectado en el índice 9497
# Drift detectado en el índice 6974
# Drift detectado en el índice 15445
# Drift detectado en el índice 15561
# Drift detectado en el índice 17086
# Drift detectado en el índice 4819
# Drift detectado en el índice 15432
# Drift detectado en el índice 15951
# Drift detectado en el índice 16636
# Drift detectado en el índice 4442
# Drift detectado en el índice 11773
# Drift detectado en el índice 16178
# Drift detectado en el índice 10374
# Drift detectado en el índice 15446
# Drift detectado en el índice 8897
# Drift detectado en el índice 15352
# Drift detectado en el índice 16081
# Drift detectado en el índice 16398
# Drift detectado en el índice 12691
# Drift detectado en el índice 15411
# Drift detectado en el índice 3634
# Drift detectado en el índice 12105
# Drift detectado en el índice 13890
# Drift detectado en el índice 15839
# Drift detectado en el índice 3592
# Drift detectado en el índice 3144
# Drift detectado en el índice 15379
# Drift detectado en el índice 15385
# Drift detectado en el índice 15699
# Drift detectado en el índice 3999
# Drift detectado en el índice 15589
# Drift detectado en el índice 6311
# Drift detectado en el índice 15986
# Drift detectado en el índice 15702
# Drift detectado en el índice 16087
# Drift detectado en el índice 12534
# Drift detectado en el índice 9620
# Drift detectado en el índice 8726
# Drift detectado en el índice 3139
# Drift detectado en el índice 16509
# Drift detectado en el índice 3743
# Drift detectado en el índice 16443
# Drift detectado en el índice 15367
# Drift detectado en el índice 9262
# Drift detectado en el índice 7416
# Drift detectado en el índice 15267
# Drift detectado en el índice 16044
# Drift detectado en el índice 16296
# Drift detectado en el índice 9073
# Drift detectado en el índice 9434
# Drift detectado en el índice 16565
# Drift detectado en el índice 11540
# Drift detectado en el índice 9841
# Drift detectado en el índice 17978
# Drift detectado en el índice 15626
# Drift detectado en el índice 13770
# Drift detectado en el índice 15600
# Drift detectado en el índice 15418
# Drift detectado en el índice 15501
# Drift detectado en el índice 15797
# Drift detectado en el índice 3224
# Drift detectado en el índice 15477
# Drift detectado en el índice 16055
# Drift detectado en el índice 10472
# Drift detectado en el índice 15655
# Drift detectado en el índice 12262
# Drift detectado en el índice 9536
# Drift detectado en el índice 15935
# Drift detectado en el índice 16001
# Drift detectado en el índice 8436
# Drift detectado en el índice 12706
# Drift detectado en el índice 4800
# Drift detectado en el índice 15920
# Drift detectado en el índice 15039
# Drift detectado en el índice 12854
# Drift detectado en el índice 15904
# Drift detectado en el índice 10583
# Drift detectado en el índice 15309
# Drift detectado en el índice 15369
# Drift detectado en el índice 15271
# Drift detectado en el índice 16059
# Drift detectado en el índice 15832
# Drift detectado en el índice 9891
# Drift detectado en el índice 11228
# Drift detectado en el índice 16505
# Drift detectado en el índice 12000
# Drift detectado en el índice 16123
# Drift detectado en el índice 15430
# Drift detectado en el índice 16008
# Drift detectado en el índice 15612
# Drift detectado en el índice 9673
# Drift detectado en el índice 15370
# Drift detectado en el índice 9978
# Drift detectado en el índice 3584
# Drift detectado en el índice 15516
# Drift detectado en el índice 7777
# Drift detectado en el índice 14329
# Drift detectado en el índice 15438
# Drift detectado en el índice 15996
# Drift detectado en el índice 5224
# Drift detectado en el índice 15835
# Drift detectado en el índice 5395
# Drift detectado en el índice 16186
# Drift detectado en el índice 4511
# Drift detectado en el índice 9985
# Drift detectado en el índice 6763
# Drift detectado en el índice 15671
# Drift detectado en el índice 14640
# Drift detectado en el índice 15098
# Drift detectado en el índice 15725
# Drift detectado en el índice 4233
# Drift detectado en el índice 15746
# Drift detectado en el índice 15862
# Drift detectado en el índice 10708
# Drift detectado en el índice 15682
# Drift detectado en el índice 3727
# Drift detectado en el índice 16006
# Drift detectado en el índice 14898
# Drift detectado en el índice 15757
# Drift detectado en el índice 3069
# Drift detectado en el índice 15754
# Drift detectado en el índice 15810
# Drift detectado en el índice 5942
# Drift detectado en el índice 17707
# Drift detectado en el índice 4261
# Drift detectado en el índice 5447
# Drift detectado en el índice 7023
# Drift detectado en el índice 9191
# Drift detectado en el índice 11222
# Drift detectado en el índice 15864
# Drift detectado en el índice 9214
# Drift detectado en el índice 15253
# Drift detectado en el índice 3291
# Drift detectado en el índice 14497
# Drift detectado en el índice 15588
# Drift detectado en el índice 15748
# Drift detectado en el índice 14555
# Drift detectado en el índice 16781
# Drift detectado en el índice 5337
# Drift detectado en el índice 15439
# Drift detectado en el índice 8079
# Drift detectado en el índice 15632
# Drift detectado en el índice 3260
# Drift detectado en el índice 4351
# Drift detectado en el índice 16566
# Drift detectado en el índice 6763
# Drift detectado en el índice 16073
# Drift detectado en el índice 11833
# Drift detectado en el índice 15873
# Drift detectado en el índice 15751
# Drift detectado en el índice 15623
# Drift detectado en el índice 16158
# Drift detectado en el índice 4136
# Drift detectado en el índice 15868
# Drift detectado en el índice 5606
# Drift detectado en el índice 15558
# Drift detectado en el índice 16059
# Drift detectado en el índice 15644
# Drift detectado en el índice 3900
# Drift detectado en el índice 17761
# Drift detectado en el índice 9060
# Drift detectado en el índice 15718
# Drift detectado en el índice 5477
# Drift detectado en el índice 4248
# Drift detectado en el índice 6018
# Drift detectado en el índice 14062
# Drift detectado en el índice 9652
# Drift detectado en el índice 15761
# Drift detectado en el índice 11489
# Drift detectado en el índice 12959
# Drift detectado en el índice 4749
# Drift detectado en el índice 3877
# Drift detectado en el índice 15557
# Drift detectado en el índice 10874
# Drift detectado en el índice 10966
# Drift detectado en el índice 15977
# Drift detectado en el índice 15703
# Drift detectado en el índice 15728
# Drift detectado en el índice 7937
# Drift detectado en el índice 16021
# Drift detectado en el índice 15767
# Drift detectado en el índice 4823
# Drift detectado en el índice 13089
# Drift detectado en el índice 4155
# Drift detectado en el índice 15432
# Drift detectado en el índice 15826
# Drift detectado en el índice 7010
# Drift detectado en el índice 15971
# Drift detectado en el índice 6010
# Drift detectado en el índice 15937
# Drift detectado en el índice 11520
# Drift detectado en el índice 15333
# Drift detectado en el índice 3312
# Drift detectado en el índice 15994
# Drift detectado en el índice 16190
# Drift detectado en el índice 16088
# Drift detectado en el índice 6017
# Drift detectado en el índice 15539
# Drift detectado en el índice 15777
# Drift detectado en el índice 15584
# Drift detectado en el índice 16121
# Drift detectado en el índice 15498
# Drift detectado en el índice 15771
# Drift detectado en el índice 15497
# Drift detectado en el índice 14950
# Drift detectado en el índice 13490
# Drift detectado en el índice 15471
# Drift detectado en el índice 13582
# Drift detectado en el índice 15376
# Drift detectado en el índice 15027
# Drift detectado en el índice 15249
# Drift detectado en el índice 15409
# Drift detectado en el índice 16122
# Drift detectado en el índice 5730
# Drift detectado en el índice 13178
# Drift detectado en el índice 15618
# Drift detectado en el índice 15408
# Drift detectado en el índice 16647
# Drift detectado en el índice 3515
# Drift detectado en el índice 16154
# Drift detectado en el índice 15354
# Drift detectado en el índice 15419
# Drift detectado en el índice 4016
# Drift detectado en el índice 4021
# Drift detectado en el índice 15722
# Drift detectado en el índice 11994
# Drift detectado en el índice 12278
# Drift detectado en el índice 15338
# Drift detectado en el índice 15570
# Drift detectado en el índice 3798
# Drift detectado en el índice 14294
# Drift detectado en el índice 13575
# Drift detectado en el índice 7174
# Drift detectado en el índice 15512
# Drift detectado en el índice 10118
# Drift detectado en el índice 8718
# Drift detectado en el índice 7897
# Drift detectado en el índice 13283
# Drift detectado en el índice 15993
# Drift detectado en el índice 15448
# Drift detectado en el índice 15347
# Drift detectado en el índice 15465
# Drift detectado en el índice 15881
# Drift detectado en el índice 15650
# Drift detectado en el índice 5558
# Drift detectado en el índice 12117
# Drift detectado en el índice 11499
# Drift detectado en el índice 6409
# Drift detectado en el índice 3149
# Drift detectado en el índice 8805
# Drift detectado en el índice 8316
# Drift detectado en el índice 6668
# Drift detectado en el índice 15747
# Drift detectado en el índice 6952
# Drift detectado en el índice 15747
# Drift detectado en el índice 9173
# Drift detectado en el índice 4158
# Drift detectado en el índice 6954
# Drift detectado en el índice 9852
# Drift detectado en el índice 5197
# Drift detectado en el índice 15458
# Drift detectado en el índice 14891
# Drift detectado en el índice 15401
# Drift detectado en el índice 15732
# Drift detectado en el índice 15426
# Drift detectado en el índice 8508
# Drift detectado en el índice 14452
# Drift detectado en el índice 15391
# Drift detectado en el índice 8404
# Drift detectado en el índice 7620
# Drift detectado en el índice 15880
# Drift detectado en el índice 10024
# Drift detectado en el índice 16415
# Drift detectado en el índice 8174
# Drift detectado en el índice 15839
# Drift detectado en el índice 15853
# Drift detectado en el índice 16041
# Drift detectado en el índice 13410
# Drift detectado en el índice 5904
# Drift detectado en el índice 5286
# Drift detectado en el índice 15433
# Drift detectado en el índice 21763
# Drift detectado en el índice 16072
# Drift detectado en el índice 6264
# Drift detectado en el índice 3170
# Drift detectado en el índice 7492
# Drift detectado en el índice 6775
# Drift detectado en el índice 15248
# Drift detectado en el índice 3568
# Drift detectado en el índice 15431
# Drift detectado en el índice 3165
# Drift detectado en el índice 6593
# Drift detectado en el índice 15490
# Drift detectado en el índice 16251
# Drift detectado en el índice 15742
# Drift detectado en el índice 10961
# Drift detectado en el índice 29090
# Drift detectado en el índice 8350
# Drift detectado en el índice 6837
# Drift detectado en el índice 13173
# Drift detectado en el índice 3257
# Drift detectado en el índice 8425
# Drift detectado en el índice 5859
# Drift detectado en el índice 14773
# Drift detectado en el índice 7212
# Drift detectado en el índice 7665
# Drift detectado en el índice 7574
# Drift detectado en el índice 16047
# Drift detectado en el índice 16950
# Drift detectado en el índice 6069
# Drift detectado en el índice 15804
# Drift detectado en el índice 8579
# Drift detectado en el índice 14434
# Drift detectado en el índice 15730
# Drift detectado en el índice 16916
# Drift detectado en el índice 10812
# Drift detectado en el índice 16238
# Drift detectado en el índice 12527
# Drift detectado en el índice 12624
# Drift detectado en el índice 15394
# Drift detectado en el índice 4452
# Drift detectado en el índice 8364
# Drift detectado en el índice 11409
# Drift detectado en el índice 5581
# Drift detectado en el índice 7194
# Drift detectado en el índice 15498
# Drift detectado en el índice 18033
# Drift detectado en el índice 8957
# Drift detectado en el índice 16193
# Drift detectado en el índice 11458
# Drift detectado en el índice 16345
# Drift detectado en el índice 15266
# Drift detectado en el índice 3643
# Drift detectado en el índice 8538
# Drift detectado en el índice 12692
# Drift detectado en el índice 15645
# Drift detectado en el índice 7971
# Drift detectado en el índice 11414
# Drift detectado en el índice 8662
# Drift detectado en el índice 16798
# Drift detectado en el índice 7237
# Drift detectado en el índice 16156
# Drift detectado en el índice 15209
# Drift detectado en el índice 15524
# Drift detectado en el índice 15452
# Drift detectado en el índice 13788
# Drift detectado en el índice 16852
# Drift detectado en el índice 3118
# Drift detectado en el índice 6571
# Drift detectado en el índice 8105
# Drift detectado en el índice 16086
# Drift detectado en el índice 15389
# Drift detectado en el índice 3792
# Drift detectado en el índice 14938
# Drift detectado en el índice 15592
# Drift detectado en el índice 16122
# Drift detectado en el índice 12677
# Drift detectado en el índice 11463
# Drift detectado en el índice 6359
# Drift detectado en el índice 15740
# Drift detectado en el índice 13694
# Drift detectado en el índice 16343
# Drift detectado en el índice 10905
# Drift detectado en el índice 5205
# Drift detectado en el índice 15458
# Drift detectado en el índice 16100
# Drift detectado en el índice 16139
# Drift detectado en el índice 15910
# Drift detectado en el índice 4361
# Drift detectado en el índice 5458
# Drift detectado en el índice 3866
# Drift detectado en el índice 15656
# Drift detectado en el índice 15811
# Drift detectado en el índice 4606
# Drift detectado en el índice 10016
# Drift detectado en el índice 15709
# Drift detectado en el índice 15781
# Drift detectado en el índice 12197
# Drift detectado en el índice 15672
# Drift detectado en el índice 15430
# Drift detectado en el índice 13164
# Drift detectado en el índice 16156
# Drift detectado en el índice 15501
# Drift detectado en el índice 15992
# Drift detectado en el índice 15844
# Drift detectado en el índice 12701
# Drift detectado en el índice 16069
# Drift detectado en el índice 4335
# Drift detectado en el índice 11990
# Drift detectado en el índice 16405
# Drift detectado en el índice 16096
# Drift detectado en el índice 15903
# Drift detectado en el índice 16850
# Drift detectado en el índice 15453
# Drift detectado en el índice 7457
# Drift detectado en el índice 12130
# Drift detectado en el índice 16063
# Drift detectado en el índice 13107
# Drift detectado en el índice 9713
# Drift detectado en el índice 15451
# Drift detectado en el índice 15392
# Drift detectado en el índice 16123
# Drift detectado en el índice 15606
# Drift detectado en el índice 16850
# Drift detectado en el índice 15849
# Drift detectado en el índice 16301
# Drift detectado en el índice 10701
# Drift detectado en el índice 3860
# Drift detectado en el índice 3164
# Drift detectado en el índice 4174
# Drift detectado en el índice 16049
# Drift detectado en el índice 15578
# Drift detectado en el índice 15985
# Drift detectado en el índice 15420
# Drift detectado en el índice 16421
# Drift detectado en el índice 16041
# Drift detectado en el índice 15909
# Drift detectado en el índice 15418
# Drift detectado en el índice 11572
# Drift detectado en el índice 13801
# Drift detectado en el índice 15404
# Drift detectado en el índice 9486
# Drift detectado en el índice 18122
# Drift detectado en el índice 15538
# Drift detectado en el índice 14917
# Drift detectado en el índice 17515
# Drift detectado en el índice 16076
# Drift detectado en el índice 4766
# Drift detectado en el índice 16087
# Drift detectado en el índice 16515
# Drift detectado en el índice 10444
# Drift detectado en el índice 15805
# Drift detectado en el índice 15274
# Drift detectado en el índice 15939
# Drift detectado en el índice 15677
# Drift detectado en el índice 13605
# Drift detectado en el índice 15597
# Drift detectado en el índice 15957
# Drift detectado en el índice 15555
# Drift detectado en el índice 15373
# Drift detectado en el índice 6482
# Drift detectado en el índice 16449
# Drift detectado en el índice 15306
# Drift detectado en el índice 15315
# Drift detectado en el índice 14088
# Drift detectado en el índice 16140
# Drift detectado en el índice 17262
# Drift detectado en el índice 16098
# Drift detectado en el índice 15718
# Drift detectado en el índice 15502
# Drift detectado en el índice 4366
# Drift detectado en el índice 4194
# Drift detectado en el índice 15643
# Drift detectado en el índice 7607
# Drift detectado en el índice 16947
# Drift detectado en el índice 3717
# Drift detectado en el índice 16165
# Drift detectado en el índice 9624
# Drift detectado en el índice 15711
# Drift detectado en el índice 15865
# Drift detectado en el índice 3151
# Drift detectado en el índice 15685
# Drift detectado en el índice 9862
# Drift detectado en el índice 16199
# Drift detectado en el índice 5192
# Drift detectado en el índice 15510
# Drift detectado en el índice 6060
# Drift detectado en el índice 8983
# Drift detectado en el índice 6235
# Drift detectado en el índice 15316
# Drift detectado en el índice 3958
# Drift detectado en el índice 15783
# Drift detectado en el índice 16168
# Drift detectado en el índice 12101
# Drift detectado en el índice 3685
# Drift detectado en el índice 15382
# Drift detectado en el índice 15422
# Drift detectado en el índice 14657
# Drift detectado en el índice 4109
# Drift detectado en el índice 14431
# Drift detectado en el índice 9784
# Drift detectado en el índice 10431
# Drift detectado en el índice 15754
# Drift detectado en el índice 15707
# Drift detectado en el índice 15857
# Drift detectado en el índice 15748
# Drift detectado en el índice 15457
# Drift detectado en el índice 15524
# Drift detectado en el índice 11059
# Drift detectado en el índice 10829
# Drift detectado en el índice 9837
# Drift detectado en el índice 3866
# Drift detectado en el índice 8591
# Drift detectado en el índice 15582
# Drift detectado en el índice 15574
# Drift detectado en el índice 15942
# Drift detectado en el índice 13903
# Drift detectado en el índice 4520
# Drift detectado en el índice 10449
# Drift detectado en el índice 16029
# Drift detectado en el índice 15391
# Drift detectado en el índice 15618
# Drift detectado en el índice 15432
# Drift detectado en el índice 7891
# Drift detectado en el índice 15985
# Drift detectado en el índice 15921
# Drift detectado en el índice 15361
# Drift detectado en el índice 7506
# Drift detectado en el índice 15753
# Drift detectado en el índice 13312
# Drift detectado en el índice 10784
# Drift detectado en el índice 11833
# Drift detectado en el índice 14637
# Drift detectado en el índice 15756
# Drift detectado en el índice 8645
# Drift detectado en el índice 15851
# Drift detectado en el índice 6014
# Drift detectado en el índice 15649
# Drift detectado en el índice 15277
# Drift detectado en el índice 16510
# Drift detectado en el índice 11456
# Drift detectado en el índice 15992
# Drift detectado en el índice 16136
# Drift detectado en el índice 15550
# Drift detectado en el índice 16152
# Drift detectado en el índice 16793
# Drift detectado en el índice 15465
# Drift detectado en el índice 11672
# Drift detectado en el índice 15807
# Drift detectado en el índice 6065
# Drift detectado en el índice 5679
# Drift detectado en el índice 15427
# Drift detectado en el índice 11560
# Drift detectado en el índice 3447
# Drift detectado en el índice 6989
# Drift detectado en el índice 10910
# Drift detectado en el índice 15709
# Drift detectado en el índice 16000
# Drift detectado en el índice 16152
# Drift detectado en el índice 15326
# Drift detectado en el índice 15637
# Drift detectado en el índice 8716
# Drift detectado en el índice 13864
# Drift detectado en el índice 8105
# Drift detectado en el índice 11356
# Drift detectado en el índice 3050
# Drift detectado en el índice 16133
# Drift detectado en el índice 15451
# Drift detectado en el índice 9366
# Drift detectado en el índice 15451
# Drift detectado en el índice 16096
# Drift detectado en el índice 4943
# Drift detectado en el índice 4055
# Drift detectado en el índice 15759
# Drift detectado en el índice 15811
# Drift detectado en el índice 3161
# Drift detectado en el índice 15916
# Drift detectado en el índice 11916
# Drift detectado en el índice 3813
# Drift detectado en el índice 9123
# Drift detectado en el índice 8877
# Drift detectado en el índice 4317
# Drift detectado en el índice 3541
# Drift detectado en el índice 16180
# Drift detectado en el índice 7140
# Drift detectado en el índice 15975
# Drift detectado en el índice 16186
# Drift detectado en el índice 7916
# Drift detectado en el índice 16032
# Drift detectado en el índice 11054
# Drift detectado en el índice 16801
# Drift detectado en el índice 15509
# Drift detectado en el índice 6920
# Drift detectado en el índice 16238
# Drift detectado en el índice 15814
# Drift detectado en el índice 15713
# Drift detectado en el índice 9474
# Drift detectado en el índice 12161
# Drift detectado en el índice 6741
# Drift detectado en el índice 4222
# Drift detectado en el índice 15809
# Drift detectado en el índice 15733
# Drift detectado en el índice 3412
# Drift detectado en el índice 8262
# Drift detectado en el índice 7148
# Drift detectado en el índice 13038
# Drift detectado en el índice 5842
# Drift detectado en el índice 15345
# Drift detectado en el índice 13519
# Drift detectado en el índice 12238
# Drift detectado en el índice 15480
# Drift detectado en el índice 6091
# Drift detectado en el índice 6406
# Drift detectado en el índice 15600
# Drift detectado en el índice 15149
# Drift detectado en el índice 15919
# Drift detectado en el índice 16100
# Drift detectado en el índice 3496
# Drift detectado en el índice 4891
# Drift detectado en el índice 15990
# Drift detectado en el índice 15747
# Drift detectado en el índice 3069
# Drift detectado en el índice 16106
# Drift detectado en el índice 15457
# Drift detectado en el índice 14611
# Drift detectado en el índice 15478
# Drift detectado en el índice 15634
# Drift detectado en el índice 5126
# Drift detectado en el índice 15720
# Drift detectado en el índice 16076
# Drift detectado en el índice 12886
# Drift detectado en el índice 15415
# Drift detectado en el índice 8709
# Drift detectado en el índice 16030
# Drift detectado en el índice 15392
# Drift detectado en el índice 16054
# Drift detectado en el índice 11505
# Drift detectado en el índice 11778
# Drift detectado en el índice 15504
# Drift detectado en el índice 5357
# Drift detectado en el índice 15708
# Drift detectado en el índice 4409
# Drift detectado en el índice 16149
# Drift detectado en el índice 11939
# Drift detectado en el índice 10816
# Drift detectado en el índice 15454
# Drift detectado en el índice 7575
# Drift detectado en el índice 11150
# Drift detectado en el índice 12840
# Drift detectado en el índice 15793
# Drift detectado en el índice 9556
# Drift detectado en el índice 3257
# Drift detectado en el índice 12580
# Drift detectado en el índice 4209
# Drift detectado en el índice 7959
# Drift detectado en el índice 24378
# Drift detectado en el índice 6348
# Drift detectado en el índice 15826
# Drift detectado en el índice 11291
# Drift detectado en el índice 17170
# Drift detectado en el índice 15441
# Drift detectado en el índice 4154
# Drift detectado en el índice 5104
# Drift detectado en el índice 15485
# Drift detectado en el índice 16673
# Drift detectado en el índice 15878
# Drift detectado en el índice 15305
# Drift detectado en el índice 3577
# Drift detectado en el índice 9806
# Drift detectado en el índice 15933
# Drift detectado en el índice 5440
# Drift detectado en el índice 5727
# Drift detectado en el índice 15536
# Drift detectado en el índice 12897
# Drift detectado en el índice 16550
# Drift detectado en el índice 12839
# Drift detectado en el índice 16107
# Drift detectado en el índice 15486
# Drift detectado en el índice 6792
# Drift detectado en el índice 9896
# Drift detectado en el índice 15407
# Drift detectado en el índice 11784
# Drift detectado en el índice 9207
# Drift detectado en el índice 15738
# Drift detectado en el índice 9238
# Drift detectado en el índice 15332
# Drift detectado en el índice 15388
# Drift detectado en el índice 20582
# Drift detectado en el índice 15820
# Drift detectado en el índice 15473
# Drift detectado en el índice 15513
# Drift detectado en el índice 7367
# Drift detectado en el índice 16333
# Drift detectado en el índice 15902
# Drift detectado en el índice 15886
# Drift detectado en el índice 5339
# Drift detectado en el índice 17191
# Drift detectado en el índice 6103
# Drift detectado en el índice 15713
# Drift detectado en el índice 16451
# Drift detectado en el índice 10856
# Drift detectado en el índice 3874
# Drift detectado en el índice 10697
# Drift detectado en el índice 3863
# Drift detectado en el índice 7431
# Drift detectado en el índice 7656
# Drift detectado en el índice 15734
# Drift detectado en el índice 10133
# Drift detectado en el índice 9230
# Drift detectado en el índice 15750
# Drift detectado en el índice 17120
# Drift detectado en el índice 15816
# Drift detectado en el índice 10176
# Drift detectado en el índice 15514
# Drift detectado en el índice 4373
# Drift detectado en el índice 6196
# Drift detectado en el índice 6931
# Drift detectado en el índice 12502
# Drift detectado en el índice 15447
# Drift detectado en el índice 11971
# Drift detectado en el índice 5631
# Drift detectado en el índice 12087
# Drift detectado en el índice 15800
# Drift detectado en el índice 14204
# Drift detectado en el índice 13220
# Drift detectado en el índice 15499
# Drift detectado en el índice 5178
# Drift detectado en el índice 16459
# Drift detectado en el índice 10790
# Drift detectado en el índice 10374
# Drift detectado en el índice 11276
# Drift detectado en el índice 15853
# Drift detectado en el índice 10977
# Drift detectado en el índice 16441
# Drift detectado en el índice 15476
# Drift detectado en el índice 9650
# Drift detectado en el índice 7212
# Drift detectado en el índice 15647
# Drift detectado en el índice 16315
# Drift detectado en el índice 15514
# Drift detectado en el índice 15598
# Drift detectado en el índice 15425
# Drift detectado en el índice 15656
# Drift detectado en el índice 6942
# Drift detectado en el índice 9746
# Drift detectado en el índice 10398
# Drift detectado en el índice 4320
# Drift detectado en el índice 16376
# Drift detectado en el índice 5704
# Drift detectado en el índice 14497
# Drift detectado en el índice 7896
# Drift detectado en el índice 5989
# Drift detectado en el índice 13307
# Drift detectado en el índice 12504
# Drift detectado en el índice 10973
# Drift detectado en el índice 15597
# Drift detectado en el índice 16110
# Drift detectado en el índice 15552
# Drift detectado en el índice 15659
# Drift detectado en el índice 12572
# Drift detectado en el índice 10407
# Drift detectado en el índice 8266
# Drift detectado en el índice 15224
# Drift detectado en el índice 10867
# Drift detectado en el índice 15427
# Drift detectado en el índice 15775
# Drift detectado en el índice 15855
# Drift detectado en el índice 16330
# Drift detectado en el índice 5359
# Drift detectado en el índice 7787
# Drift detectado en el índice 14521
# Drift detectado en el índice 7196
# Drift detectado en el índice 16083
# Drift detectado en el índice 15814
# Drift detectado en el índice 3243
# Drift detectado en el índice 8030
# Drift detectado en el índice 4165
# Drift detectado en el índice 15281
# Drift detectado en el índice 12415
# Drift detectado en el índice 15796
# Drift detectado en el índice 14181
# Drift detectado en el índice 4861
# Drift detectado en el índice 7157
# Drift detectado en el índice 8716
# Drift detectado en el índice 10935
# Drift detectado en el índice 15766
# Drift detectado en el índice 16360
# Drift detectado en el índice 15454
# Drift detectado en el índice 7890
# Drift detectado en el índice 16113
# Drift detectado en el índice 15815
# Drift detectado en el índice 3668
# Drift detectado en el índice 16259
# Drift detectado en el índice 16792
# Drift detectado en el índice 15424
# Drift detectado en el índice 15687
# Drift detectado en el índice 14590
# Drift detectado en el índice 3957
# Drift detectado en el índice 15796
# Drift detectado en el índice 15590
# Drift detectado en el índice 15738
# Drift detectado en el índice 12366
# Drift detectado en el índice 7824
# Drift detectado en el índice 16823
# Drift detectado en el índice 3513
# Drift detectado en el índice 13168
# Drift detectado en el índice 15758
# Drift detectado en el índice 13666
# Drift detectado en el índice 15393
# Drift detectado en el índice 16934
# Drift detectado en el índice 7866
# Drift detectado en el índice 6089
# Drift detectado en el índice 15497
# Drift detectado en el índice 16151
# Drift detectado en el índice 12041
# Drift detectado en el índice 15714
# Drift detectado en el índice 16589
# Drift detectado en el índice 10604
# Drift detectado en el índice 6033
# Drift detectado en el índice 8864
# Drift detectado en el índice 16209
# Drift detectado en el índice 15480
# Drift detectado en el índice 6787
# Drift detectado en el índice 6182
# Drift detectado en el índice 7448
# Drift detectado en el índice 15540
# Drift detectado en el índice 8755
# Drift detectado en el índice 15564
# Drift detectado en el índice 5547
# Drift detectado en el índice 11719
# Drift detectado en el índice 15697
# Drift detectado en el índice 15564
# Drift detectado en el índice 5657
# Drift detectado en el índice 15413
# Drift detectado en el índice 4957
# Drift detectado en el índice 15640
# Drift detectado en el índice 15631
# Drift detectado en el índice 15313
# Drift detectado en el índice 15956
# Drift detectado en el índice 11673
# Drift detectado en el índice 16020
# Drift detectado en el índice 13406
# Drift detectado en el índice 17241
# Drift detectado en el índice 11932
# Drift detectado en el índice 15621
# Drift detectado en el índice 15844
# Drift detectado en el índice 15439
# Drift detectado en el índice 16142
# Drift detectado en el índice 15330
# Drift detectado en el índice 15939
# Drift detectado en el índice 4436
# Drift detectado en el índice 15982
# Drift detectado en el índice 5139
# Drift detectado en el índice 4870
# Drift detectado en el índice 8286
# Drift detectado en el índice 13993
# Drift detectado en el índice 15429
# Drift detectado en el índice 14770
# Drift detectado en el índice 3067
# Drift detectado en el índice 13909
# Drift detectado en el índice 16281
# Drift detectado en el índice 15963
# Drift detectado en el índice 16091
# Drift detectado en el índice 15867
# Drift detectado en el índice 13715
# Drift detectado en el índice 7048
# Drift detectado en el índice 11013
# Drift detectado en el índice 15046
# Drift detectado en el índice 16258
# Drift detectado en el índice 15493
# Drift detectado en el índice 3831
# Drift detectado en el índice 10420
# Drift detectado en el índice 15750
# Drift detectado en el índice 3635
# Drift detectado en el índice 14376
# Drift detectado en el índice 15543
# Drift detectado en el índice 15414
# Drift detectado en el índice 15673
# Drift detectado en el índice 15545
# Drift detectado en el índice 8188
# Drift detectado en el índice 3963
# Drift detectado en el índice 7326
# Drift detectado en el índice 15221
# Drift detectado en el índice 15406
# Drift detectado en el índice 4540
# Drift detectado en el índice 8759
# Drift detectado en el índice 9442
# Drift detectado en el índice 15436
# Drift detectado en el índice 16047
# Drift detectado en el índice 15888
# Drift detectado en el índice 15813
# Drift detectado en el índice 7201
# Drift detectado en el índice 15775
# Drift detectado en el índice 15252
# Drift detectado en el índice 15304
# Drift detectado en el índice 16440
# Drift detectado en el índice 15382
# Drift detectado en el índice 8672
# Drift detectado en el índice 15249
# Drift detectado en el índice 16457
# Drift detectado en el índice 15208
# Drift detectado en el índice 7348
# Drift detectado en el índice 16264
# Drift detectado en el índice 16234
# Drift detectado en el índice 14855
# Drift detectado en el índice 18003
# Drift detectado en el índice 5188
# Drift detectado en el índice 15623
# Drift detectado en el índice 16044
# Drift detectado en el índice 16649
# Drift detectado en el índice 3694
# Drift detectado en el índice 3511
# Drift detectado en el índice 11480
# Drift detectado en el índice 5197
# Drift detectado en el índice 8229
# Drift detectado en el índice 10799
# Drift detectado en el índice 15606
# Drift detectado en el índice 16022
# Drift detectado en el índice 4324
# Drift detectado en el índice 15494
# Drift detectado en el índice 4851
# Drift detectado en el índice 15420
# Drift detectado en el índice 15736
# Drift detectado en el índice 15015
# Drift detectado en el índice 6839
# Drift detectado en el índice 5473
# Drift detectado en el índice 8847
# Drift detectado en el índice 11319
# Drift detectado en el índice 8948
# Drift detectado en el índice 11319
# Drift detectado en el índice 13384
# Drift detectado en el índice 15186
# Drift detectado en el índice 26349
# Drift detectado en el índice 5403
# Drift detectado en el índice 8131
# Drift detectado en el índice 15652
# Drift detectado en el índice 4751
# Drift detectado en el índice 7370
# Drift detectado en el índice 15493
# Drift detectado en el índice 15415
# Drift detectado en el índice 15392
# Drift detectado en el índice 16027
# Drift detectado en el índice 13901
# Drift detectado en el índice 7261
# Drift detectado en el índice 12561
# Drift detectado en el índice 16428
# Drift detectado en el índice 16449
# Drift detectado en el índice 16223
# Drift detectado en el índice 7975
# Drift detectado en el índice 15158
# Drift detectado en el índice 15419
# Drift detectado en el índice 15415
# Drift detectado en el índice 16068
# Drift detectado en el índice 4977
# Drift detectado en el índice 15687
# Drift detectado en el índice 15542
# Drift detectado en el índice 10450
# Drift detectado en el índice 9540
# Drift detectado en el índice 11738
# Drift detectado en el índice 15823
# Drift detectado en el índice 5779
# Drift detectado en el índice 15732
# Drift detectado en el índice 15768
# Drift detectado en el índice 15774
# Drift detectado en el índice 16102
# Drift detectado en el índice 13343
# Drift detectado en el índice 12594
# Drift detectado en el índice 15691
# Drift detectado en el índice 8834
# Drift detectado en el índice 14834
# Drift detectado en el índice 11088
# Drift detectado en el índice 15771
# Drift detectado en el índice 15535
# Drift detectado en el índice 12827
# Drift detectado en el índice 4264
# Drift detectado en el índice 14060
# Drift detectado en el índice 15530
# Drift detectado en el índice 5683
# Drift detectado en el índice 12119
# Drift detectado en el índice 4933
# Drift detectado en el índice 4102
# Drift detectado en el índice 15521
# Drift detectado en el índice 11286
# Drift detectado en el índice 15774
# Drift detectado en el índice 8514
# Drift detectado en el índice 11554
# Drift detectado en el índice 8552
# Drift detectado en el índice 15697
# Drift detectado en el índice 8643
# Drift detectado en el índice 16016
# Drift detectado en el índice 4363
# Drift detectado en el índice 15344
# Drift detectado en el índice 15474
# Drift detectado en el índice 16498
# Drift detectado en el índice 12934
# Drift detectado en el índice 15365
# Drift detectado en el índice 15004
# Drift detectado en el índice 15736
# Drift detectado en el índice 16103
# Drift detectado en el índice 15284
# Drift detectado en el índice 5905
# Drift detectado en el índice 6448
# Drift detectado en el índice 7283
# Drift detectado en el índice 16746
# Drift detectado en el índice 8158
# Drift detectado en el índice 3205
# Drift detectado en el índice 15983
# Drift detectado en el índice 15497
# Drift detectado en el índice 11838
# Drift detectado en el índice 16464
# Drift detectado en el índice 15445
# Drift detectado en el índice 15386
# Drift detectado en el índice 16054

# %%
guardar_estadisticas("KSWIN", "gradual", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 501
# FAR: 0.50402
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# MDR: 0.021
# Tiempo de ejecucion: 11372.02084183693

# %% [markdown]
# #### Distribucion exponencial

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.1, distribucion="exponential")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15034

# %%
guardar_estadisticas("KSWIN", "gradual", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 0
# FAR: 0.0
# MDR: 0.0
# Tiempo de ejecucion: 15.252921342849731

# %% [markdown]
# #### Distribucion gamma

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []

tiempo_total = 0

for i in range(num_iteracciones): 

    kswin = drift.KSWIN(alpha=0.0001, window_size=3000, stat_size=300,seed=42)
 
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.1, distribucion="gamma")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin, 100, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15179

# %%
guardar_estadisticas("KSWIN", "gradual", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 0
# FAR: 0.0
# MDR: 0.0
# Tiempo de ejecucion: 14.975170612335205

# %% [markdown]
# ## KSWIN Modificado (Configuración 1 y 2)

# %% [markdown]
# ### Abrupt drift

# %% [markdown]
# #### Distribucion normal (configuracion 2)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, alternative='two-sided', configuracion=2, es_continua=True)
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.05, distribucion="normal")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15299

# %%
guardar_estadisticas("KSWIN_modificado", "abrupto", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 14
# FAR: 0.01449
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# MDR: 0.035
# Tiempo de ejecucion: 532.1567285060883

# %% [markdown]
# #### Distribucion normal (configuracion 1)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, alternative='two-sided', configuracion=1, es_continua=True)
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.05, distribucion="normal")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14999
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 8699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 12299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 26399
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 11699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14399
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 11999
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 14999
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 4499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 11099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 4799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 8699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 7199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 6299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 8399
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 7799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 9299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 13199
# Drift detectado en el índice 15299
# Drift detectado en el índice 10799
# Drift detectado en el índice 15299
# Drift detectado en el índice 10199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 3599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 11099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 6899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 5099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 8099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 10199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "abrupto", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 30
# FAR: 0.03125
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# Drift drift_abrupto en el punto {'punto': 15000, 'detectado': False} no detectado
# MDR: 0.041
# Tiempo de ejecucion: 15673.32651925087
# c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# #### Distribucion exponencial (configuracion 2)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, alternative='two-sided', configuracion=2, es_continua=True)
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.05, distribucion="exponential")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado", "abrupto", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion exponencial (configuracion 1)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, alternative='two-sided', configuracion=1, es_continua=True)
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.05, distribucion="exponential")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "abrupto", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion gamma (configuracion 2)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, alternative='two-sided', configuracion=2, es_continua=True)
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.05, distribucion="gamma")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado", "abrupto", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion gamma (configuracion 1)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0

for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, alternative='two-sided', configuracion=1, es_continua=True)
    data_noisy, drifts = crear_dataset_abrupto_General(seed_aux=23 + i, ruido_std=0.05, distribucion="gamma")

    drifts_totales.append(drifts)

    # plot_data(data_noisy, None, drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "abrupto", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# ### Incremental drift

# %% [markdown]
# #### Distribucion normal (configuracion 2)

# %%
num_iteracciones = 1000


puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=2, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.05, distribucion="normal")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 17699
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 20099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17999
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 17999
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 14099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 4799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 11999
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 6899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17999
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 11699
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 18899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 17399
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 8399
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 17399
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 14999
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 3899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 3899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 17699
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 17699
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 17099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 18599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 17999
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17699
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 18599
# Drift detectado en el índice 7799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 8999
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 17699
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 9299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 17099
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 17099
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 3599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 12299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299

# %%
guardar_estadisticas("KSWIN_modificado", "incremental", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 37
# FAR: 0.03903
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# MDR: 0.075
# Tiempo de ejecucion: 604.824422121048

# %% [markdown]
# #### Distribucion normal (configuracion 1)

# %%
num_iteracciones = 1000


puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=1, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.05, distribucion="normal")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 3599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 7799
# Drift detectado en el índice 17699
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 12599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 17999
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 14099
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 5699
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 11999
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17399
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 18599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17699
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 12899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 13499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 11699
# Drift detectado en el índice 15299
# Drift detectado en el índice 4499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 7799
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 23
#      19 drifts_totales.append(drifts)
#      21 tiempo_inicial = time.time()
# ---> 23 puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)
#      26 tiempo_total += time.time() - tiempo_inicial
#      28 # plot_data(data_noisy, puntos_detectados_aux, drifts)
#
# Cell In[5], line 52, in realizar_deteccion(dataset, drifts, detector, longitud_batch, falsas_alarmas, imprimir_mensajes)
#      49 if len(batch_detector) == batch_detector.maxlen:
#      51     if isinstance(detector, KSWIN_modificado):
# ---> 52         detector.update(batch_detector)
#      53     else:
#      54         detector.update(val)
#
# File c:\Users\Fernando\Desktop\TFG\TFG\TFGInfo\Codigo\Matematicas\KSWIN_modificado.py:292, in KSWIN_modificado.update(self, x)
#     290 with warnings.catch_warnings():
#     291     warnings.simplefilter("ignore", category=RuntimeWarning)
# --> 292     st, self.p_value = stats.ks_2samp(most_recent, less_recent, method="auto", alternative=self.alternative)
#     294 p_values.append(self.p_value)
#     296 #Corrección de BENJAMINI-HOCHBERG
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     529 if sentinel:
#     530     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531 res = hypotest_fun_out(*samples, **kwds)
#     532 res = result_to_tuple(res)
#     533 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\scipy\_lib\_util.py:794, in _rename_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     792         raise TypeError(message)
#     793     kwargs[new_name] = kwargs.pop(old_name)
# --> 794 return fun(*args, **kwargs)
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\scipy\stats\_stats_py.py:8739, in ks_2samp(data1, data2, alternative, method)
#    8737 if np.ma.is_masked(data2):
#    8738     data2 = data2.compressed()
# -> 8739 data1 = np.sort(data1)
#    8740 data2 = np.sort(data2)
#    8741 n1 = data1.shape[0]
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\numpy\core\fromnumeric.py:1017, in sort(a, axis, kind, order)
#    1015 else:
#    1016     a = asanyarray(a).copy(order="K")
# -> 1017 a.sort(axis=axis, kind=kind, order=order)
#    1018 return a
#
# KeyboardInterrupt:

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "incremental", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion exponencial (configuracion 2)

# %%
num_iteracciones = 1000


puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=2, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.05, distribucion="exponential")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# Drift detectado en el índice 15299
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      19 drifts_totales.append(drifts)
#      21 tiempo_inicial = time.time()
# ---> 23 puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)
#      26 tiempo_total += time.time() - tiempo_inicial
#      28 # plot_data(data_noisy, puntos_detectados_aux, drifts)
#
# Cell In[5], line 52, in realizar_deteccion(dataset, drifts, detector, longitud_batch, falsas_alarmas, imprimir_mensajes)
#      49 if len(batch_detector) == batch_detector.maxlen:
#      51     if isinstance(detector, KSWIN_modificado):
# ---> 52         detector.update(batch_detector)
#      53     else:
#      54         detector.update(val)
#
# File c:\Users\Fernando\Desktop\TFG\TFG\TFGInfo\Codigo\Experimentación_v3\KSWIN_modificado.py:376, in KSWIN_modificado.update(self, x)
#     374 with warnings.catch_warnings():
#     375     warnings.simplefilter("ignore", category=RuntimeWarning)
# --> 376     st, self.p_value = stats.ks_2samp(most_recent, less_recent, method="auto", alternative=self.alternative)
#     378 p_values.append(self.p_value)
#     380 #Corrección de BENJAMINI-HOCHBERG
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     529 if sentinel:
#     530     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531 res = hypotest_fun_out(*samples, **kwds)
#     532 res = result_to_tuple(res)
#     533 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\scipy\_lib\_util.py:794, in _rename_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     792         raise TypeError(message)
#     793     kwargs[new_name] = kwargs.pop(old_name)
# --> 794 return fun(*args, **kwargs)
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\scipy\stats\_stats_py.py:8739, in ks_2samp(data1, data2, alternative, method)
#    8737 if np.ma.is_masked(data2):
#    8738     data2 = data2.compressed()
# -> 8739 data1 = np.sort(data1)
#    8740 data2 = np.sort(data2)
#    8741 n1 = data1.shape[0]
#
# File c:\Users\Fernando\miniconda3\envs\EntornoTFG\Lib\site-packages\numpy\core\fromnumeric.py:1017, in sort(a, axis, kind, order)
#    1015 else:
#    1016     a = asanyarray(a).copy(order="K")
# -> 1017 a.sort(axis=axis, kind=kind, order=order)
#    1018 return a
#
# KeyboardInterrupt:

# %%
guardar_estadisticas("KSWIN_modificado", "incremental", "exponential",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion gamma (configuracion 2)

# %%
num_iteracciones = 1000


puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=2, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.05, distribucion="gamma")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado", "incremental", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion exponencial (configuracion 1)

# %%
num_iteracciones = 1000


puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=1, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.05, distribucion="exponential")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "incremental", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion gamma (configuracion 1)

# %%
num_iteracciones = 1000


puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=1, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_incremental_General(seed_aux=24 + i, ruido_std=0.05, distribucion="gamma")

    drifts_totales.append(drifts)

    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)


    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)

    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "incremental", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# ### Gradual drift

# %% [markdown]
# #### Distribucion normal (configuracion 2)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=2, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.05, distribucion="normal")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)
# Out:
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 10799
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 17399
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 17399
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 17999
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 17699
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 4799
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 11999
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 4499
# Drift detectado en el índice 16199
# Drift detectado en el índice 6899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17699
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15299
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 11099
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 18899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 17699
# Drift detectado en el índice 16199
# Drift detectado en el índice 11699
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 8699
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 8399
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 2999
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 14999
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 11999
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 3899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16799
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 3899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 17699
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 17399
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17399
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 7799
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 4199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 17399
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 12899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 17399
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 17699
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 13199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 17399
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 7499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 17099
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 15299
# Drift detectado en el índice 17099
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 15299
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 17399
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15599
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 15899
# Drift detectado en el índice 16799
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16499
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 15899
# Drift detectado en el índice 16199
# Drift detectado en el índice 15299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 16199
# Drift detectado en el índice 16799
# Drift detectado en el índice 16499
# Drift detectado en el índice 16199
# Drift detectado en el índice 15599
# Drift detectado en el índice 12299
# Drift detectado en el índice 16499
# Drift detectado en el índice 15599
# Drift detectado en el índice 15599
# Drift detectado en el índice 16799

# %%
guardar_estadisticas("KSWIN_modificado", "gradual", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
# Out:
# Numero de falsas alarmas 37
# FAR: 0.03907
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 16000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 17000, 'detectado': False} no detectado
# Drift drift_incremental en el punto {'inicio': 15000, 'fin': 18000, 'detectado': False} no detectado
# MDR: 0.07
# Tiempo de ejecucion: 1047.2091963291168

# %% [markdown]
# #### Distribucion normal (configuracion 1)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=1, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.05, distribucion="normal")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "gradual", "normal",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion exponencial(configuracion 2)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=2, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.05, distribucion="exponential")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado", "gradual", "exponential",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion gamma (configuracion 2)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=2, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.05, distribucion="gamma")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado", "gradual", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion exponencial (configuracion 1)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=1, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.05, distribucion="exponential")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "gradual", "exponencial",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)

# %% [markdown]
# #### Distribucion gamma (configuracion 1)

# %%
num_iteracciones = 1000

puntos_detectados = []
falsas_alarmas = []
drifts_totales = []
tiempo_total = 0
 
for i in range(num_iteracciones): 
    
    kswin_modificado = KSWIN_modificado(alpha=0.001, window_start=0, window_size=3000, stat_size=300, confirm_drift=False, configuracion=1, alternative='two-sided', es_continua=True)
    data_noisy, drifts = crear_dataset_gradual_General(seed_aux=25 + i, ruido_std=0.05, distribucion="gamma")

    drifts_totales.append(drifts)


    tiempo_inicial = time.time()

    puntos_detectados_aux, falsas_alarmas_aux = realizar_deteccion(data_noisy, drifts,  kswin_modificado, 300, [], True)

    tiempo_total += time.time() - tiempo_inicial

    # plot_data(data_noisy, puntos_detectados_aux, drifts)


    puntos_detectados.extend(puntos_detectados_aux)
    falsas_alarmas.extend(falsas_alarmas_aux)

# %%
guardar_estadisticas("KSWIN_modificado (config original)", "gradual", "gamma",drifts_totales, puntos_detectados, falsas_alarmas, tiempo_total)
